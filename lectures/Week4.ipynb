# %% [markdown]
# # Overview
#
# This week is all about working with data. I'm not going to lie to you. This part might be frustrating - but frustration is an integral part of learning. Real data is almost always messy & difficult ... and learning to deal with that fact, is a key part of being a data scientist.
#
# Enough about the process, let's get to the content! Welcome to ... (drumroll drumroll drumroll)

# %% [markdown]
# # <center> The Legend of Zelda: Breath of the Wild </center>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("zw47_q9wbBE",width=800, height=450)

# %% [markdown]
# Today, we will use network science and the [Zelda Wiki](https://zelda.fandom.com/wiki/Main_Page) to learn about the relationships of BotW characters.
#
# To create the network, we will download the Zelda Wiki pages for all characters in BotW (enemies and bosses included). Next, we will create the network of the pages that link to each other. Since wiki pages not only link to [Link](https://zelda.fandom.com/wiki/Link) but also to each other (Anna: "yes.. I know.. bad joke -- but come on our hero's name is Link!!!! I can't help myself"). So [Link](https://zelda.fandom.com/wiki/Link) links to  [Princess Zelda](https://zelda.fandom.com/wiki/Princess_Zelda) and viceversa, for example.
#
# Next time, we'll use our network skills (as well as new ones) to understand that network. Further down the line, we'll use natural language processing to understand the text displayed on those pages.
#
# But for today, the tasks are:
#
# * Learn about regular expressions
# * Learn about Pandas dataframes
# * Download and store (for later use) all characters and their pages from the Zelda Wiki
# * Extract all the internal wiki-links that connect the characters on the Zelda Wiki
# * Generate the network of characters from the Zelda Wiki.
# * Calculate some simple network statistics.

# %% [markdown]
# ---
#
# # Prelude part 1: Regular expressions
#
# Before we get started, we have to get a little head start on the _Natural Language Processing_ part of the class. This is a new direction for us, up to now, we've mostly been doing math-y stuff with Python, but today, we're going to be using Python to work through a text. The central thing we need to be able to do today, is to extract internal wiki links. And for that we need regular expressions.
#
# > _Exercises_: Regular expressions round 1\.
# >
# > * Read [**this tutorial**](https://developers.google.com/edu/python/regular-expressions) to form an overview of regular expressions. This is important to understand the content of the tutorial (also very useful later), so you may actually want to work through the examples.
# > * Now, explain in your own words: what are regular expressions?
# > * Provide an example of a regex to match 4 digits numbers (by this, I mean precisely 4 digits, you should not match any part of numbers with e.g. 5 digits). In your notebook, use `findall` to show that your regex works on this [test-text](https://raw.githubusercontent.com/SocialComplexityLab/socialgraphs2021/main/files/regex_exercise.txt). **Hint**: a great place to test out regular expressions is: https://regex101.com.
# > * Provide an example of a regex to match words starting with "super". Show that it works on the [test-text](https://raw.githubusercontent.com/SocialComplexityLab/socialgraphs2021/main/files/regex_exercise.txt).
# >

# %%
import re

# %%
f = open("C:\\Users\\bgran\\OneDrive - Danmarks Tekniske Universitet\\studies\\Social Graphs and Interactions\\socialgraphs2021\\files\\regex_exercise.txt", "r")

# %%
contents = f.read()

# %%
re.findall(r"[0-9]{4}", contents)
# Out:
# ['1234', '9999', '2345']

# %%
re.findall(r"\bsuper\w*\b", contents)
# Out:
# ['superpolaroid', 'supertaxidermy', 'superbeer']

# %% [markdown]
# Finally, we need to figure out how to match internal Zelda wiki links. Zelda wiki links come in different [flavors](https://zelda.fandom.com/wiki/Guidelines:Getting_Started). First, let's focus on those linking to pages directly (this step will help us collecting the list of characters).
#
# Direct links are always enclosed in double square brackets, e.g. `[[name of character]]`, or double curly brackets, `{{Term|Series|name of character|link}}` and occur like this:
#
#     ... some text [[Princess Zelda]] some more text ...
#     ... some text {{Term|BotW|Princess Zelda|link}} some more text ...
#
# both linking to the page [`https://zelda.fandom.com/wiki/Princess_Zelda`](https://zelda.fandom.com/wiki/Princess_Zelda).
#
# The second type of link uses text that is different from the page name, here's an example:
#
#     ... some text [[Princess Zelda|Zelda]] some more text ...
#     ... some text {{Term|BotW|Princess Zelda|link|display=Zelda}} some more text ...
#
# both still linking to the page [`https://zelda.fandom.com/wiki/Princess_Zelda`](https://zelda.fandom.com/wiki/Princess_Zelda). Note that there are many series of The Legend of Zelda, but, because we are going to focus on Breath of the Wild (BotW) and to make our data collection a little bit easier, we will **not look for direct links to other series** even if characters can be recurrent (i.e. we will look for links in double curly brackets always in the form `{{Term|BotW|name of character|link}}`).

# %% [markdown]
# Now it's your turn.
#
# > _Exercise_: Regular expressions round 2\. Show that you can extract the direct Zelda wiki links from the [Zelda test-text](https://raw.githubusercontent.com/SocialComplexityLab/socialgraphs2021/main/files/Zelda_regex_exercise.txt). Perhaps you can find inspiration on stack overflow or similar. **Hint**: Try to solve this exercise on your own (that's what you will get the most out of - learning wise), but if you get stuck ... you will find the solution in one of the video lectures below.
# >

# %%
f = open("C:\\Users\\bgran\\OneDrive - Danmarks Tekniske Universitet\\studies\\Social Graphs and Interactions\\socialgraphs2021\\files\\Zelda_regex_exercise.txt", "r")
contents = f.read()

# %%
re.findall(r"\[\[.*?\]\]|\{\{.*?\}\}", contents)
# Out:
# ['[[Champion]]',
#  '{{Term|BotW|Link|link}}',
#  '{{Term|BotW|Calamity Ganon|link|display=Ganon}}',
#  '[[Urbosa]]',
#  '[[Goron City]]',
#  '{{Term|BotW|Divine Beast Vah Rudania|link}}',
#  '[[Daruk]]',
#  '[[Eldin (Region)|Eldin]]',
#  '[[Master Sword|Sword]]']

# %% [markdown]
# # Prelude part 2: Pandas DataFrames

# %% [markdown]
# Before starting, we will also learn a bit about [pandas dataframes](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html), a very user-friendly data structure that you can use to manipulate tabular data. Pandas dataframes are implemented within the [pandas package](https://pandas.pydata.org/).
#
# Pandas dataframes should be intuitive to use. **We suggest you to go through the [10 minutes to Pandas tutorial](https://pandas.pydata.org/pandas-docs/version/0.22/10min.html#min) to learn what you need to solve the next exercise.**

# %% [markdown]
# ---
#
# # Part A: Download the Zelda Wikipages of characters

# %% [markdown]
# It's time to download all of the pages of the characters. Use your experience with APIs from Week 1\. To get started, I **strongly** recommend that you re-watch the **APIs video lecture** from that week - it contains lots of useful tips on this specific activity (yes, we had planned this all along!). I've included it below for your covenience.

# %%
YouTubeVideo("9l5zOfh0CRo",width=800, height=450)

# %% [markdown]
# Now, to download the Zelda wiki pages of characters, we first need to collect the list of all characters in BotW, starting from the following pages:
#
# 1. [The list of allies](https://zelda.fandom.com/wiki/Characters_in_Breath_of_the_Wild)
# 2. [The list of enemies](https://zelda.fandom.com/wiki/Enemies_in_Breath_of_the_Wild)
# 3. [The list of bosses](https://zelda.fandom.com/wiki/Bosses_in_Breath_of_the_Wild)

# %% [markdown]
# >
# >  _Exercise 1_: Collect the list of BotW Characters
# >
# > If you open any of the pages above, you will quickly see that characters are divided by their location in the game (allies) or type (enemies and bosses) and organized alphabetically, but, most importantly, their names are displayed in the form of links to their page. This means that if we use regular expressions to detect all links in the page description we will find them all! Let's get started:
# > 1. for each page above, find the baseurl and title and build the related API query (add the parameter `rvslots=*` to your query's content)
# > 2. use the query to collect the page (you can save it in a json file for future use) and extract its content
# > 3. build a regular expression to find all characters' names (**hint**: all links in these pages have the same format, i.e. `{{Term|Series|name of character|link}}`)
# > 4. add the characters names and their role (i.e. "Ally", "Enemy", and "Boss") in a Pandas DataFrame. How many unique characters did you find? How many of them are allies, enemies, and bosses? Are there any repeated characters? If so, drop the duplicates, then save the data in a csv file
# >
# > **Note**:
# > 1. In the Enemies page there is a section called "Traps", we do not want to include this list in our dataset
# > 2. Some Bosses have a link in *parenthesis* to their location in the game, you should filter these links out

# %%
import requests
import json

# %%
address = 'https://zelda.fandom.com/api.php?'
action="action=query"
titles="titles=Characters_in_Breath_of_the_Wild"
content="prop=revisions&rvslots=*&rvprop=content"
dataformat="format=json"
query = '%s%s&%s&%s&%s' % (address, action, titles, content, dataformat)

# %%
response = requests.get(query)
content = response.json()

# %%
content['query']['pages']['77604']['revisions'][0]['slots']['main']['*']
# Out:
# '{{DISPLAYTITLE: Characters in {{BotW|-}}}}\nThe following is a list of characters from {{BotW}}.\n\n==Greater {{Term|BotW|Hyrule}}==\n<gallery>\nFile:BotW Baddek Model.png|{{Term|BotW|Baddek|link}}<!-- Hebra and Central Hyrule -->\nFile:BotW Bamboo Model.png|{{Term|BotW|Bamboo|link}}<!-- Baumar\'s Horse -->\nFile:BotW Banji Model.png|{{Term|BotW|Banji|link}}<!-- Tabantha Bridge Stable -->\nFile:BotW Baumar Model.png|{{Term|BotW|Baumar|link}}<!-- Hebra and Eldin -->\nFile:BotW Bayge Model.png|{{Term|BotW|Bayge|link}}\nFile:BotW Beedle Model.png|{{Term|BotW|Beedle|link}}\nFile:BotW Bolson Model.png|{{Term|BotW|Bolson|link}}\nFile:BotW Brigo Model.png|{{Term|BotW|Brigo|link}}\nFile:BotW Cambo Model.png|{{Term|BotW|Cambo|link}}<!-- West Necluda and Lanayru Wetlands -->\nFile:BotW Chabi Model.png|{{Term|BotW|Chabi|link}}\nFile:BotW Chork Model.png|{{Term|BotW|Chork|link}}<!-- Tabantha Bridge Stable -->\nFile:BotW Chumin Model.png|{{Term|BotW|Chumin|link}}\nFile:BotW Dabi Model.png|{{Term|BotW|Dabi|link}}<!-- Tabantha Bridge Stable -->\nFile:BotW Daruk Artwork.png|{{Term|BotW|Daruk|link}}\nFile:BotW Dauntless Model.png|{{Term|BotW|Dauntless|link}}<!-- Nazbi\'s Horse -->\nFile:BotW Dinraal Model.png|{{Term|BotW|Dinraal|link}}\nFile:BotW Ena Model.png|{{Term|BotW|Ena|link}}<!-- Tabantha Bridge Stable -->\nFile:BotW Endai Model.png|{{Term|BotW|Endai|link}}<!-- West Necluda and Lanayru Wetlands -->\nFile:BotW Epona Model.png|{{Term|BotW|Epona|link}}\nFile:BotW Farosh Model.png|{{Term|BotW|Farosh|link}}\nFile:BotW Fyson Model.png|{{Term|BotW|Fyson|link}}\nFile BotW Goflam Model.png|{{Term|BotW|Goflam|link}}\nFile:BotW Greyson Model.png|{{Term|BotW|Greyson|link}}\nFile:BotW Heehl Model.png|{{Term|BotW|Heehl|link}}\nFile:BotW Hestu Model.png|{{Term|BotW|Hestu|link}}\nFile:BotW Hudson Model.png|{{Term|BotW|Hudson|link}}\nFile:BotW Hylia Model.png|{{Term|BotW|Hylia|link}}\nFile:BotW Kabetta Model.png|{{Term|BotW|Kabetta|link}}\nFile:BotW Kanny Model.png|{{Term|BotW|Kanny|link}}<!-- Hebra and Eldin -->\nFile:BotW Kapson Model.png|{{Term|BotW|Kapson|link}}\nFile:BotW Karson Model.png|{{Term|BotW|Karson|link}}\nFile:BotW Kass Model.png|{{Term|BotW|Kass|link}}\nFile:BotW Kenyo Model.png|{{Term|BotW|Kenyo|link}}<!-- Tabantha Bridge Stable -->\nFile:BotW Kilton Model.png|{{Term|BotW|Kilton|link}}\nFile:BotW Leekah Model.png|{{Term|BotW|Leekah|link}}<!-- Hyrule Field, Lanayru Wetlands and Eldin Canyon -->\nFile:BotW Link Artwork.png|{{Term|BotW|Link|link}}\nFile:BotW Meeshy Model.png|{{Term|BotW|Meeshy|link}}\nFile:BotW Meghyn Model.png|{{Term|BotW|Meghyn|link}}\nFile:BotW Mei Model.png|{{Term|BotW|Mei|link}}<!-- Faron and Lanayru -->\nFile:BotW Mils Model.png|{{Term|BotW|Mils|link}}\nFile:BotW Mina Model.png|{{Term|BotW|Mina|link}}\nFile:BotW Mipha Artwork.png|{{Term|BotW|Mipha|link}}\nFile:No Image.png|{{Term|BotW|Misko|link}}\nFile:BotW Nat Model.png|{{Term|BotW|Nat|link}}\nFile:BotW Naydra Model.png|{{Term|BotW|Naydra|link}}\nFile:BotW Nazbi Model.png|{{Term|BotW|Nazbi|link}}<!-- Hebra and Eldin -->\nFile:BotW Pelison Model.png|{{Term|BotW|Pelison|link}}\nFile:BotW Pikango Model.png|{{Term|BotW|Pikango|link}}\nFile:BotW Regan Model.png|{{Term|BotW|Regan|link}}\nFile:BotW Revali Artwork.png|{{Term|BotW|Revali|link}}\nFile:BotW Rhondson Model.png|{{Term|BotW|Rhondson|link}}<!-- Gerudo and Akkala -->\nFile:BotW Rik Model.png|{{Term|BotW|Rik|link}}<!-- West Necluda and Lanayru Wetlands -->\nFile:BotW Ronn Model.png|{{Term|BotW|Ronn|link}}<!-- Hebra and Eldin -->\nFile:BotW Savelle Model.png|{{Term|BotW|Savelle|link}}<!-- Eldin, Central Hyrule -->\nFile:BotW Sherfin Model.png|{{Term|BotW|Sherfin|link}}\nFile:BotW Sho Model.png|{{Term|BotW|Sho|link}}<!-- Tabantha Bridge Stable -->\nFile:BotW Sorelia Model.png|{{Term|BotW|Sorelia|link}}\nFile:BotW Spoone Model.png|{{Term|BotW|Spoone|link}}<!-- West Necluda and Lanayru Wetlands -->\nFile:BotW Toren Model.png|{{Term|BotW|Toren|link}}<!-- Tabantha Bridge Stable -->\nFile:BotW Totsuna Model.png|{{Term|Bo ...

# %%
content_allies = response.text

# %%
allies = re.findall(r"Term[\w\| \(\)\'\\]*?link", content_allies)

# %%
address = 'https://zelda.fandom.com/api.php?'
action="action=query"
titles="titles=Enemies_in_Breath_of_the_Wild"
content="prop=revisions&rvslots=*&rvprop=content"
dataformat="format=json"
query = '%s%s&%s&%s&%s' % (address, action, titles, content, dataformat)
response = requests.get(query)
content_enemies = response.text


content_enemies = re.findall(r".*(?=Traps)", content_enemies)[0]
enemies = re.findall(r"Term[\w\| \(\)\'\\]*?link", content_enemies)

# %%
address = 'https://zelda.fandom.com/api.php?'
action="action=query"
titles="titles=Bosses_in_Breath_of_the_Wild"
content="prop=revisions&rvslots=*&rvprop=content"
dataformat="format=json"
query = '%s%s&%s&%s&%s' % (address, action, titles, content, dataformat)
response = requests.get(query)
content_bosses = response.text

bosses = re.findall(r"Term[\w\| \(\)\'\\]*?link", content_bosses)

# %%
allies_names = [re.findall(r"(?:.*?\|){2}(.*)?\|", ally)[0].split("(")[0] for ally in allies]
enemies_names = [re.findall(r"(?:.*?\|){2}(.*)?\|", enemy)[0].split("(")[0] for enemy in enemies]
bosses_names = [re.findall(r"(?:.*?\|){2}(.*)?\|", boss)[0].split("(")[0] for boss in bosses]

# %%
bosses_names = [
    'Calamity Ganon',
    'Stalnox',
    'Windblight Ganon',
    'Molduking',
    'Molduga',
    'Thunderblight Ganon',
    'Igneo Talus',
    'Dark Beast Ganon',
    'Waterblight Ganon',
    'Frost Talus',
    'Monk Maz Koshia',
    'Hinox',
    'Master Kohga',
    'Fireblight Ganon',
    'Stone Talus',
    'Blue Hinox',
    'Igneo Talus Titan',
    'Black Hinox',
    'Stone Talus '
]

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'name': allies_names+enemies_names+bosses_names,
    'role': ['ally']*len(allies_names)+['enemy']*len(enemies_names)+['boss']*len(bosses_names)
})

# %%
df.name = [name[0] for name in df.name.str.split("(")]

# %%
df.drop_duplicates(inplace=True)

# %%
df.name = df.name.str.strip()

# %%
df.replace(' ', '_', regex=True, inplace = True)

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# You've made it! Now, you have a clean file listing all characters in BotW and their role. By following the same strategy you used to download the pages above, you can now use the API and download each character page. For each character, save the resulting page content in a txt file.
#
# **Note**:
# 1. the name of the character corresponds to the title of its page (where spaces are replaced with underscores). So, the title of `Princess Zelda`'s page is `Princess_Zelda`
# 2. some of your character's names could actually redirect to a different page. Add a check to find any redirect in a page description. (**hint**: the description will be in the form `#REDIRECT [[PAGENAME]]` so you should use `PAGENAME` in your query instead)

# %%
df = df[~df.name.str.contains("Grant")]

# %%
for char in ['Abstract_Tech']:#df.name:
#     address = 'https://zelda.fandom.com/api.php?'
    address = 'https://aesthetics.fandom.com/api.php?'
    action="action=query"
    titles=f"titles={char}"
#     content="prop=extracts&exlimit=1&explaintext"
    content="prop=revisions&rvslots=*&rvprop=content"
    dataformat="format=json"
    query = '%s%s&%s&%s&%s' % (address, action, titles, content, dataformat)
    response = requests.get(query)
    content_char = response.text
#     with open(f'characters/{char}.txt', 'w') as f:
#         f.write(content_char)

# %%
content_char
# Out:
# '{"batchcomplete":"","query":{"normalized":[{"from":"Abstract_Tech","to":"Abstract Tech"}],"pages":{"18672":{"pageid":18672,"ns":0,"title":"Abstract Tech","revisions":[{"slots":{"main":{"contentmodel":"wikitext","contentformat":"text/x-wiki","*":"{{Aesthetic|other_names = Abstract Futuristic / Cyber / Digital / High-Tech; Sci-Fi Interface / FUI|decade_of_origin = c. 1990s-2000s (?)|key_motifs = glowing lines, concentric arcs/circles, hexagons, circuits, binary code, connected dots, robotics|image1 = Cyber-security.jpg|caption1=The future is now.|key_colours = blue, black, white|key_values = technological advancement, digital transformation, connectivity|related_media = \'\'Minority Report\'\', \'\'Iron Man\'\' (MCU), \'\'TRON: Legacy\'\', other Digital Age sci-fi, technology stock images|related_aesthetics=[[Corporate]] <br> [[Cyberprep]] <br> [[Cyberpunk]] <br> [[Frutiger Aero]] <br> [[Hexatron]] <br> [[Intel Core]] <br> [[Metalheart]] <br> [[Technocore]] <br> [[Y2K]]}}\\n\\nThe \'\'\'Abstract Tech\'\'\' aesthetic consists of design motifs, such as concentric arcs, hexagons, or circuit patterns, that are intended to evoke a sense of something being futuristic or technologically advanced. \\n\\nThis aesthetic can be found in user interfaces, depictions of cyberspace, and other technological imagery in science fiction media of the Digital Age, such as the interfaces from \'\'Minority Report\'\' (2002) and \'\'Iron Man\'\' (2008), or the video game \'\'TRON 2.0\'\' (2003) and the film \'\'TRON: Legacy\'\' (2010), as well as stock images and backgrounds/wallpapers related to keywords like \\"technology,\\" \\"high-tech,\\" \\"digital,\\" or \\"cyber.\\"\\n\\n== Visuals ==\\nBecause many aspects and concepts related to software and digital technology are intangible, many people have resorted to using common abstract symbolism to signify the use of said technologies. An early example would be \'\'TRON\'\' (1982), which depicted a digital world with glowing lines and circles and partly inspired the [[Synthwave]] aesthetic. \'\'The Matrix\'\' (1999) is also notable for representing a simulated reality as green raining digital code, which became associated with computer hacking.\\n\\nAccording to designer Chris Noessel, the color blue became common in late-20th-century science fiction as it was associated with unnatural or artificial things.<ref>[https://99percentinvisible.org/episode/future-screens-are-mostly-blue/ Future Screens are Mostly Blue]<br /></ref> However, the use of this aesthetic in its current form to portray the concept of \\"technology\\" would not become widespread until the 21st century with the increasing popularity of the Internet and the influence of sci-fi anime like \'\'Ghost in the Shell\'\' and live action movies like \'\'Minority Report\'\'.\\n\\nAbstract design motifs often described as \\"high-tech\\" include:\\n\\n* Glowing lines, usually blue or white (or glowing blue backgrounds)\\n* Transparent or holographic touchscreen interfaces\\n* Segmented concentric arcs and circles of varying thicknesses\\n* Hexagons, a simple, yet advanced and efficient (higher area-to-perimeter ratio, and tileable) shape\\n* Printed circuit board patterns, found in most electronic devices\\n* Binary numbers, the basis of most digital signals and data, or other forms of computer code\\n* Dots connected by lines, representing the Internet or connectivity\\n* Concepts of robots or robotic body parts\\n\\nIn stock images, symbols such as locks (representing cybersecurity) or the shape of a brain (representing artificial intelligence) may be combined with the aforementioned motifs as well. The use of technology in business may be portrayed as a businessperson tapping a floating touchscreen with the associated design elements. By the late 2010s, some commentators considered this stock imagery to be clich\\u00e9.<ref>[https://goldenspiralmarketing.com/insights/19-hilariously-bad-stock-photo-attempts-at-visualizing-tech/ 19 Hilarious ...

# %%
related = re.findall(r'(?<=related_aesthetics =).*?(?=\=)', content_char)[0]

# %%
re.findall(r'(?<=\[\[).*?(?=\]\])', related)
# Out:
# ['Deathrock',
#  'Glam Rock',
#  'Post-Punk',
#  'Punk',
#  'Shoegaze',
#  'Trad Goth',
#  'Black',
#  'Bubble Goth',
#  'Christcore',
#  'Corporate',
#  'Cybergoth',
#  'Darkest Academia',
#  'Emo',
#  'Gothic',
#  'Health Goth',
#  'Rivethead',
#  'Metal',
#  'Nu-Goth',
#  'Nu-Metal',
#  'Pastel Goth',
#  'Punk',
#  'Romantic Goth',
#  'Southern Gothic',
#  'Synthwave',
#  'Weirdcore',
#  'White',
#  'Woodland Goth']

# %%
G = nx.DiGraph()
for index, row in df.iterrows():
    char = row['name']
    role = row.role
    with open(f'characters/{char}.txt') as f:
        contents = f.read()
        if re.findall(pattern_race1, contents) or re.findall(pattern_race2, contents):
#             race = re.split(r'\(|\|', (re.findall(pattern_race1, contents)+re.findall(pattern_race2, contents))[0])[0]
            race = (re.findall(pattern_race1, contents)+re.findall(pattern_race2, contents))[0]
#         if re.findall(pattern_race, contents):    
#             race = re.findall(pattern_race, contents)[0]
        else:
            race = "unknown"
#         print(race)
        if re.findall(pattern_gender, contents) and re.findall(pattern_gender, contents) != ['']:
            gender = re.findall(pattern_gender, contents)[0]
        else: 
            gender = "unknown"
        G.add_node(char, role=role, race=race, gender=gender)

# %%
# !pip install wikia
# Out:
# Collecting wikia
#   Downloading wikia-1.4.4-py3-none-any.whl (10 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\bgran\anaconda3\lib\site-packages (from wikia) (4.9.3)
# Requirement already satisfied: requests<3.0.0,>=2.3.0 in c:\users\bgran\anaconda3\lib\site-packages (from wikia) (2.24.0)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\bgran\anaconda3\lib\site-packages (from beautifulsoup4->wikia) (2.0.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\bgran\anaconda3\lib\site-packages (from requests<3.0.0,>=2.3.0->wikia) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\bgran\anaconda3\lib\site-packages (from requests<3.0.0,>=2.3.0->wikia) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\bgran\anaconda3\lib\site-packages (from requests<3.0.0,>=2.3.0->wikia) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bgran\anaconda3\lib\site-packages (from requests<3.0.0,>=2.3.0->wikia) (2020.6.20)
# Installing collected packages: wikia
# Successfully installed wikia-1.4.4

# %%
import wikia

# %%
goth  = wikia.page("Aesthetics", "Goth")

# %%
goth.summary
# Out:
# 'NSFW Content Warning: This page does make a brief mention about "Fetish Goth", which combines the Goth aesthetic with BDSM themes. This article discusses Goth music and the subculture surrounding it. For the art and literature that predated it, see Gothic. Goth is a music-based subculture that was formed in the late 1970s-to-early 1980s in the UK. Gothic rock originally derived from the post-punk movement at the time, which included acts, such as Joy Division, the Siouxsie and the Banshees. "Got'

# %%
goth.sections
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-b607961af843> in <module>
# ----> 1 goth.sections
#
# ~\anaconda3\lib\site-packages\wikia\wikia.py in sections(self)
#     443
#     444       request = _wiki_request(query_params)
# --> 445       self._sections = [section['title'] for section in request['sections']]
#     446
#     447     return self._sections
#
# KeyError: 'sections'

# %% [markdown]
# ---
#
# # Part B: Building the network
#
# Now, we're going to build the BotW NetworkX directed graph, which includes all good characters, enemies, and bosses.
#
# The nodes in the network will be all the characters, and we will place an edge between nodes $A$ and $B$ if the Zelda wiki page of node $A$ links to the Zelda Wiki page of node $B$.

# %%
YouTubeVideo("eciQ6qgRD-4", width=800, height=450)

# %%
YouTubeVideo("J7SF0Xs2PHM", width=800, height=450)

# %% [markdown]
# > _Exercise 1_: Build the network of BotW Characters
# >
# > Now we can build the network. Isn't this a little bit cool? What a dataset :)
# >
# > The overall strategy for this is the following:
# > Take the pages you have downloaded for each character.
# > Each page corresponds to a character, which is a node in your network.
# > Find the Race and Gender of a character in their Infobox and use regular expressions to extract them. Then, find all the hyperlinks in a character's page that link to another node of the network (e.g. another character).
# > There are many ways to do this, but below, I've tried to break it down into natural steps.
# > Keep in mind that the network should include all characters (allies, enemies, and bosses).
# >
# >
# > * Use regular expressions to extract all outgoing links from each of the pages you downloaded above. Remember that links have different [flavors](https://zelda.fandom.com/wiki/Guidelines:Getting_Started), these are the ones we need (they seem a lot but you've already built the patterns in 1. and 2. and just need to add a condition to them):
#       1. direct links, i.e. [[name of character]] or {{Term|BotW|name of character|link}}
#       2. links using text, i.e. [[Princess Zelda|Zelda]] or {{Term|Series|Princess Zelda|link|display=Zelda}}
#       3. links to pages that have parentheses, i.e. [[Ocarina of Time (Item)|]] or {{Term|Series|Ocarina of Time (Item)|link}}
#       4. links using plural terms, i.e. [[Heart]]s or {{Plural|Series|Heart|link}}
#       5. links to sections of another page, i.e. [[Link#Breath of the Wild]] or {{Term|BotW|Link|link}}
# >
# > * For each link you extract, check if the target is a character. If yes, keep it. If no, discard it.
# > * Use a NetworkX [`DiGraph`](https://networkx.github.io/documentation/development/reference/classes.digraph.html) to store the network. Store also the properties of the nodes (i.e. Role, Race, and Gender).
# > * When you have finished, you'll notice that some nodes do not have any edge. Those are isolated nodes, you may *discard* them from the network.
# >
# > **Note**: When you add a node to the network, also include an `attribute` for each node characteristic (i.e. an attribute that specifies Role, Race, and Gender)

# %%
import networkx as nx

# %%
pattern_race1 = r'race= \[\[(\w*)'
pattern_race2 = r'race= \{\{Term\|BotW\|(.*?)[\(\|\}]'
pattern_gender = r'gender= (\w*)+'

# %%
G = nx.DiGraph()
for index, row in df.iterrows():
    char = row['name']
    role = row.role
    with open(f'characters/{char}.txt') as f:
        contents = f.read()
        if re.findall(pattern_race1, contents) or re.findall(pattern_race2, contents):
#             race = re.split(r'\(|\|', (re.findall(pattern_race1, contents)+re.findall(pattern_race2, contents))[0])[0]
            race = (re.findall(pattern_race1, contents)+re.findall(pattern_race2, contents))[0]
#         if re.findall(pattern_race, contents):    
#             race = re.findall(pattern_race, contents)[0]
        else:
            race = "unknown"
#         print(race)
        if re.findall(pattern_gender, contents) and re.findall(pattern_gender, contents) != ['']:
            gender = re.findall(pattern_gender, contents)[0]
        else: 
            gender = "unknown"
        G.add_node(char, role=role, race=race, gender=gender)

# %%
contents
# Out:
# '{"batchcomplete":"","query":{"normalized":[{"from":"Stone_Talus","to":"Stone Talus"}],"pages":{"77756":{"pageid":77756,"ns":0,"title":"Stone Talus","revisions":[{"slots":{"main":{"contentmodel":"wikitext","contentformat":"text/x-wiki","*":"{{Infobox Boss\\n|type= \\n|image= \\n{{Media\\n |Model BotW= File:BotW Stone Talus Model.png\\n |Model StBotW= File:StBotW Stone Talus Model.png\\n}}\\n|caption= \\n|pronunciation= \\n|plural= Stone Taluses<ref>{{Cite|Let\'s see how many {{Color|BotW Blue|Stone Taluses}} you\'ve harvested so far... Looks like [X] out of 40.|Kilton|BotW}}</ref>\\n|title= \\n|race= \\n|gender= \\n|game= {{BotW}}<br>{{StBotW}}\\n|other= {{CoH}}<br>{{HWAoC}}\\n|dungeon= \\n|habitat= See [[#Locations|below]]\\n|health= 300<br>600 {{Small|(Luminous)}}<br>900 {{Small|(Rare)}}\\n|weakness= {{Term|BotW|Iron Sledgehammer|link}}<br>{{Plural|BotW|Bomb Arrow|link}}\\n|reward= [[Flint]]<br>{{Term|BotW|Amber|link}}<br>{{Term|BotW|Opal|link}}<br>{{Term|BotW|Ruby|link}}\\n|exp= \\n|theme= \\n|strategy=\\n|voice actor= \\n}}\\n{{Term/Store|Stone Talus|Stone Taluses|Series, BotW, CoH}} are recurring enemies and {{Plural|Series|Sub-Boss|link}} in {{TLoZ|Series}}.<ref>{{Cite|\'\'\'{{Color|BotW Shrine Quest|Stone Talus}}\'\'\'|Hyrule Compendium|BotW}}</ref><ref>{{Cite|Defeated By: Stone Talus|Game Over|CoH}}</ref>\\n\\n==Characteristics==\\n==={{BotW|-}}===\\n{{Compendium/Extract|Stone Talus}}\\n{{Plural|BotW|Stone Talus}} appear as a cluster of boulders at first, but once approached, they assemble into large golem-like beings. {{Term|BotW|Stone Talus (Luminous)|link|display= Luminous}}, {{Term|BotW|Stone Talus (Rare)|link|display= Rare}}, {{Term|BotW|Frost Talus|link|display= Frost}}, and {{Term|BotW|Igneo Talus|link|display= Igneo}} variations can also be found all around {{Term|BotW|Hyrule|link}}. {{Plural|BotW|Stone Talus}} are fairly large compared and deal important amounts of damage.{{How many}} They are very slow-moving, so as long as {{Term|BotW|Link|link}} stays behind or beneath them, he will be out of harm\'s way. {{Plural|BotW|Stone Talus}} can use their large arm structures to punch and swipe across the ground, dealing heavy damage to the impact area. They can also fall forward and crash their entire body into the ground or launch large fragments of their rocky frame at {{Term|BotW|Link}}. \\n\\nTo defeat a {{Term|BotW|Stone Talus}}, {{Term|BotW|Link}} can climb onto its body and attack the {{Term|BotW|Ore Deposit|link}} on its back, usually located on top or at the back of the {{Term|BotW|Sub-Boss|link}}. {{Term|BotW|Link}} can inflict major damage by using a double-handed {{Term|BotW|Weapon|link}} or {{Plural|BotW|Bomb Arrow|link}}. After taking damage, {{Plural|BotW|Stone Talus}} attempt to throw {{Term|BotW|Link}} off by shaking themselves. To make climbing easier, {{Term|BotW|Link}} can use a {{Term|BotW|Remote Bomb|link}} to blast apart its arms, hindering it temporarily. {{Plural|BotW|Stone Talus}} regenerate lost body parts shortly after losing them. If you can\'t climb onto it, stun it with a normal arrow, shooting the {{Term|BotW|Ore Deposit|link}} on its back, making it fall on its face. If you are new to Taluses, we recommend trying the Stone Talus Senior or the Stone Talus Junior first.   \\n\\nUpon being defeated, a {{Term|BotW|Stone Talus}} leaves behind {{Plural|BotW|Gem|link}} depending of its type. By defeating all Stone Taluses in {{Term|BotW|Hyrule Kingdom|link}}, as well as all other types of Talus, Link can receive the [[Medal of Honor: Talus]] from [[Kilton]]. This can only be done after completing the \\"[[Destroy Ganon]]\\" [[Main Quest]].\\n\\n====Locations====\\n* {{Term|BotW|Great Plateau|link}}\\n* {{Term|BotW|Deya Lake|link}}\\n* {{Term|BotW|North Dueling Peaks|link}} (Senior)\\n* {{Term|BotW|Dueling Peaks South|link}} (Junior)\\n* {{Term|BotW|West Nabi Lake|link}}\\n* {{Term|BotW|North Mable Ridge|link}}\\n* {{Term|BotW|Martha\'s Landing|link}}\\n* {{Term|BotW|Lake Floria|link}}\\n*  ...

# %%
nx.get_node_attributes(G, 'gender')
# Out:
# {'Baddek': 'Male',
#  'Bamboo': 'unknown',
#  'Banji': 'Female',
#  'Baumar': 'Male',
#  'Bayge': 'Male',
#  'Beedle': 'Male',
#  'Bolson': 'Male',
#  'Brigo': 'Male',
#  'Cambo': 'Male',
#  'Chabi': 'Female',
#  'Chork': 'Male',
#  'Chumin': 'Male',
#  'Dabi': 'Male',
#  'Daruk': 'Male',
#  'Dauntless': 'unknown',
#  'Dinraal': 'unknown',
#  'Ena': 'unknown',
#  'Endai': 'Male',
#  'Epona': 'Female',
#  'Farosh': 'unknown',
#  'Fyson': 'Male',
#  'Goflam': 'unknown',
#  'Greyson': 'Male',
#  'Heehl': 'Male',
#  'Hestu': 'Male',
#  'Hudson': 'Male',
#  'Hylia': 'Female',
#  'Kabetta': 'Male',
#  'Kanny': 'unknown',
#  'Kapson': 'Male',
#  'Karson': 'Male',
#  'Kass': 'Male',
#  'Kenyo': 'unknown',
#  'Kilton': 'Male',
#  'Leekah': 'Female',
#  'Link': 'Male',
#  'Meeshy': 'unknown',
#  'Meghyn': 'Female',
#  'Mei': 'Female',
#  'Mils': 'Male',
#  'Mina': 'Female',
#  'Mipha': 'Female',
#  'Misko': 'Unknown',
#  'Nat': 'Female',
#  'Naydra': 'unknown',
#  'Nazbi': 'Male',
#  'Pelison': 'Male',
#  'Pikango': 'Male',
#  'Regan': 'Male',
#  'Revali': 'Male',
#  'Rhondson': 'Female',
#  'Rik': 'unknown',
#  'Ronn': 'unknown',
#  'Savelle': 'Male',
#  'Sherfin': 'unknown',
#  'Sho': 'unknown',
#  'Sorelia': 'unknown',
#  'Spoone': 'unknown',
#  'Toren': 'unknown',
#  'Totsuna': 'unknown',
#  'Tye': 'unknown',
#  'Urbosa': 'Female',
#  'Yammo': 'unknown',
#  'Princess_Zelda': 'Female',
#  'Zyle': 'Male',
#  'Laroba': 'Female',
#  'Naddon': 'Male',
#  'Pitar': 'unknown',
#  'Dah_Hesho': 'unknown',
#  'Dmitri': 'Male',
#  'Gleema': 'Female',
#  'Jana': 'Female',
#  'Kah_Mael': 'unknown',
#  'Kaifa': 'Female',
#  "Ke'nai_Shakah": 'unknown',
#  'Lonni': 'unknown',
#  'Nell': 'Male',
#  'Rex': 'Male',
#  'Stamm': 'unknown',
#  'Tenne': 'Female',
#  'Tutsuwa_Nima': 'unknown',
#  'Ze_Kasho': 'unknown',
#  'Hagie': 'Male',
#  'Hunnie': 'Female',
#  'Moggs': 'unknown',
#  'Monari': 'Female',
#  'Ruli': 'Female',
#  'Ritaag_Zumo': 'unknown',
#  "Tu_Ka'loh": 'unknown',
#  'Aya': 'Female',
#  'Cherry': 'unknown',
#  'Hoz': 'Male',
#  'Jerrin': 'Female',
#  'Katosa_Aug': 'unknown',
#  'Khini': 'unknown',
#  'Nobo': 'unknown',
#  'Robbie': 'Male',
#  'Rudi': 'unknown',
#  'Zuna_Kai': 'unknown',
#  'Glendo': 'unknown',
#  'King_Rhoam': 'Male',
#  'Etsu_Korima': 'unknown',
#  'Ja_Baij': 'unknown',
#  'Keh_Namut': 'unknown',
#  'Old_Man': 'Male',
#  'Oman_Au': 'unknown',
#  'Owa_Daim': 'unknown',
#  'Rohta_Chigah': 'unknown',
#  'Ruvo_Korbah': 'unknown',
#  'Yowaka_Ita': 'unknown',
#  'Aliza': 'Female',
#  'Benny': 'Female',
#  'Bosh_Kala': 'unknown',
#  'Botrick': 'Male',
#  'Calamity_Ganon': 'Male',
#  'Canni': 'Female',
#  'Dah_Kaso': 'unknown',
#  'Dai': 'Male',
#  'Gotter': 'Male',
#  'Haite': 'Female',
#  "Kaam_Ya'tak": 'unknown',
#  'Katah_Chuki': 'unknown',
#  'Monya_Toma': 'unknown',
#  'Myti': 'unknown',
#  'Namika_Ozz': 'unknown',
#  'Noya_Neha': 'unknown',
#  'Parcy': 'Female',
#  'Rota_Ooh': 'unknown',
#  "Saas_Ko'sah": 'unknown',
#  'Toffa': 'Male',
#  'Trott': 'Male',
#  'Wahgo_Katta': 'unknown',
#  'Zalta_Wa': 'unknown',
#  'Branli': 'Male',
#  'Konba': 'Male',
#  "Maag_No'rah": 'unknown',
#  'Mijah_Rokee': 'unknown',
#  'Mogg_Latan': 'unknown',
#  'Shira_Gomar': 'unknown',
#  'Toh_Yahsa': 'unknown',
#  'Yunobo': 'Male',
#  'Ashe': 'Male',
#  'Axyl': 'Male',
#  'Bladon': 'Male',
#  'Bohrin': 'Male',
#  'Boldon': 'Male',
#  'Breen': 'Female',
#  'Daqa_Koh': 'unknown',
#  'Dayto': 'unknown',
#  'Dorill': 'Male',
#  'Douma': 'unknown',
#  'Drak': 'Male',
#  'Dugby': 'Male',
#  'Fin': 'unknown',
#  'Gaile': 'unknown',
#  'Gonguron': 'Male',
#  'Gorae_Torr': 'unknown',
#  'Grapp': 'Male',
#  'Jengo': 'Male',
#  'Kairo': 'Male',
#  'Karsh': 'unknown',
#  'Kayra_Mah': 'unknown',
#  'Kima': 'unknown',
#  'Kish': 'unknown',
#  'Mayro': 'unknown',
#  'Mirro_Shaz': 'unknown',
#  "Mo'a_Keet": 'unknown',
#  'Molo': 'unknown',
#  'Offrak': 'Male',
#  'Ozunda': 'unknown',
#  'Qua_Raym': 'unknown',
#  'Russ': 'unknown',
#  'Sah_Dahaj': 'unknown',
#  'Shamae': 'unknown',
#  'Shora_Hah': 'unknown',
#  'Tah_Muhl': 'unknown',
#  'Zorona': 'unknown',
#  'Aji': 'Male',
#  'Bargoh': 'Male',
#  'Bludo': 'Male',
#  'Fugo': 'Male',
#  'Krane': 'Male',
#  'Pyle': 'Male',
#  'Ramella': 'unknown',
#  'Rogaro': 'Male',
#  'Rohan': 'Male',
#  "Shae_Mo'sah": 'unknown',
#  'Slergo': 'Male',
#  'Tanko': 'Male',
#  'Tray': 'Male',
#  'Volcon': 'Male',
#  'Akrah': 'Male',
#  'Daag_Chokah': 'unknown',
#  'Garshon': 'unknown',
#  'Ketoh_Wawai': 'unknown',
#  'Kuhn_Sidajj': 'unknown',
#  'Maag_Halan': 'unknown',
#  'Oaki': 'unknown',
#  'Onya': 'unknown',
#  'Sprinn': 'unknown',
#  'Tasho': 'unknown',
#  'Zooki': 'unknown',
#  'Zumi': 'unknown',
#  'Chio': 'Male',
#  'Damia': 'unknown',
#  'Daz': 'unknown',
#  'Keo_Ruug': 'unknown',
#  'Kula': 'unknown',
#  'Maca': 'unknown',
#  'Natie': 'unknown',
#  'Peeks': 'unknown',
#  'Pepp': 'unknown',
#  'The_Great_Deku_Tree': 'Male',
#  'Walton': 'unknown',
#  'Blynne': 'Male',
#  'Jini': 'unknown',
#  "Ka'o_Makagh": 'unknown',
#  'Loone': 'Female',
#  'Malanya': 'Male',
#  'Padok': 'unknown',
#  'Perosa': 'unknown',
#  'Phanna': 'Female',
#  'Pumaag_Nitae': 'unknown',
#  'Roscoe': 'unknown',
#  'Shae_Katha': 'unknown',
#  'Shoqa_Tatone': 'unknown',
#  'Straia': 'unknown',
#  'Suzuna': 'unknown',
#  'Ya_Naga': 'unknown',
#  'Barta': 'Female',
#  'Calisa': 'Female',
#  'Eighth_Heroine': 'Female',
#  'Gartan': 'Male',
#  'Lukan': 'Female',
#  'Seven_Heroines': 'unknown',
#  'Anche': 'Female',
#  'Benja': 'Male',
#  'Dako_Tah': 'unknown',
#  'Daqo_Chisay': 'unknown',
#  'Dila_Maag': 'unknown',
#  'Dillie': 'Male',
#  'Hawa_Koth': 'unknown',
#  'Jee_Noh': 'unknown',
#  'Jora': 'Male',
#  'Kay_Noh': 'unknown',
#  'Keive_Tala': 'unknown',
#  'Kema_Zoos': 'unknown',
#  'Konora': 'Female',
#  "Korsh_O'hu": 'unknown',
#  'Kyra': 'Female',
#  'Misae_Suma': 'unknown',
#  'Patricia': 'Female',
#  'Pokki': 'Female',
#  'Raqa_Zunzo': 'unknown',
#  'Riju': 'Female',
#  'Shabonne': 'Female',
#  'Strade': 'Male',
#  'Sudrey': 'Female',
#  'Takama_Shiri': 'unknown',
#  'Tali': 'Female',
#  'Tera': 'Female',
#  'Tho_Kayu': 'unknown',
#  'Ardin': 'Female',
#  'Ashai': 'Female',
#  'Aurie_Taamu': 'Male',
#  'Babi': 'Female',
#  'Bertri': 'Female',
#  'Bozai': 'Male',
#  'Buliara': 'Female',
#  'Calyban': 'Female',
#  'Cara': 'Female',
#  'Dalia': 'Female',
#  'Danda': 'Female',
#  'Deltan': 'Female',
#  'Dina': 'Female',
#  'Dorrah': 'Female',
#  'Essa': 'Female',
#  'Estan': 'Female',
#  'Fegran': 'Female',
#  'Frelly': 'Female',
#  'Frita': 'Female',
#  'Furosa': 'Female',
#  'Greta': 'Female',
#  'Isha': 'Female',
#  'Jules': 'Female',
#  'Kalani': 'Female',
#  'Katta': 'Female',
#  'Kohm': 'Female',
#  'Kotta': 'Female',
#  'Laine': 'Female',
#  'Lashley': 'Female',
#  'Leena': 'Female',
#  'Liana': 'Female',
#  'Lorn': 'Female',
#  'Lyndae': 'Male',
#  'Makure': 'Female',
#  'Malena': 'Female',
#  'Marta': 'Female',
#  'Merina': 'Female',
#  'Muava': 'Female',
#  'Nali': 'Female',
#  'Nellie': 'Female',
#  'Olu': 'Female',
#  'Padda': 'Female',
#  'Pasha': 'Female',
#  'Pearle': 'Female',
#  'Ploka': 'Female',
#  'Pritana': 'Female',
#  'Pyra': 'Female',
#  'Reeza': 'Female',
#  'Rima': 'Female',
#  'Risa': 'Female',
#  'Romah': 'Female',
#  'Rotana': 'Female',
#  'Saula': 'Female',
#  'Smaude': 'Female',
#  'Spera': 'Female',
#  'Sumati': 'Female',
#  'Tauma': 'Female',
#  'Teake': 'Female',
#  'Traysi': 'Female',
#  'Yaido': 'Female',
#  'Emri': 'Female',
#  'Guy': 'Male',
#  'Kachoo': 'Female',
#  'Maike': 'Female',
#  'Nobiro': 'Male',
#  'Ripp': 'Female',
#  'Robsten': 'Male',
#  'Shaillu': 'Female',
#  'Vilia': 'Female',
#  'Canolo': 'Female',
#  'Flaxel': 'Female',
#  'Ishto_Soh': 'unknown',
#  'Joloo_Nah': 'unknown',
#  'Keeha_Yoog': 'unknown',
#  'Kema_Kosassa': 'unknown',
#  'Kihiro_Moh': 'unknown',
#  'Kuh_Takkar': 'unknown',
#  'Master_Kohga': 'Male',
#  'Maypin': 'Male',
#  'Moza': 'Female',
#  'Oliff': 'Male',
#  'Palme': 'Male',
#  'Piaffe': 'Male',
#  'Pirou': 'Male',
#  'Sasa_Kai': 'unknown',
#  'Sesami': 'Male',
#  'Sho_Dantu': 'unknown',
#  'Suma_Sahma': 'unknown',
#  'Falmark': 'Male',
#  'Teba': 'Male',
#  'Tulin': 'Male',
#  'Goma_Asaagh': 'unknown',
#  'Hia_Miu': 'unknown',
#  'Kiah_Toza': 'unknown',
#  'Maka_Rah': 'unknown',
#  'Mozo_Shenno': 'unknown',
#  'Noe_Rajee': 'unknown',
#  'Qaza_Tokki': 'unknown',
#  'Rok_Uwog': 'unknown',
#  'Selmie': 'unknown',
#  'Sha_Warvo': 'unknown',
#  'Shada_Naw': 'unknown',
#  'To_Quomo': 'unknown',
#  'Danton': 'Male',
#  'Harlow': 'Female',
#  'Harry': 'unknown',
#  'Juannelle': 'unknown',
#  'Mary': 'unknown',
#  'Monkton': 'Male',
#  'Rin_Oyaa': 'unknown',
#  'Sha_Gehma': 'unknown',
#  'Varke': 'unknown',
#  'Ariane': 'Female',
#  'Bareeda_Naag': 'unknown',
#  'Cree': 'unknown',
#  'Dunba_Taag': 'unknown',
#  'Galli': 'unknown',
#  "Gee_Ha'rah": 'unknown',
#  'Geggle': 'unknown',
#  'Genli': 'unknown',
#  'Gesane': 'unknown',
#  'Kah_Okeo': 'unknown',
#  'Kaysa': 'Female',
#  'Kheel': 'Female',
#  'Kotts': 'unknown',
#  'Lanno_Kooh': 'unknown',
#  'Lester': 'unknown',
#  'Modar': 'Male',
#  'Molli': 'Female',
#  'Notts': 'unknown',
#  'Pondo': 'unknown',
#  'Ponthos': 'Male',
#  'Rona_Kachta': 'unknown',
#  'Shae_Loya': 'unknown',
#  'Sheem_Dagoze': 'unknown',
#  "Tena_Ko'sah": 'unknown',
#  'Voo_Lota': 'unknown',
#  "Akh_Va'quot": 'unknown',
#  'Amali': 'Female',
#  'Bedoli': 'Female',
#  'Cecili': 'Female',
#  'Harth': 'Male',
#  'Huck': 'Male',
#  'Jogo': 'Male',
#  'Juney': 'Female',
#  'Kaneli': 'Male',
#  'Laissa': 'Female',
#  'Mazli': 'Male',
#  'Misa': 'Female',
#  'Nekk': 'Male',
#  'Saki': 'Female',
#  'Verla': 'unknown',
#  'Gruve': 'Male',
#  'Ledo': 'unknown',
#  'Tona': 'Female',
#  'Tottika': 'Male',
#  'Tula': 'Female',
#  'Eryck': 'Male',
#  'Dagah_Keek': 'unknown',
#  'Mezza_Lo': 'unknown',
#  'Rucco_Maag': 'unknown',
#  'Sidon': 'unknown',
#  'Soh_Kofi': 'unknown',
#  'Torfeau': 'Female',
#  'Bazz': 'Male',
#  'Cleff': 'Male',
#  'Dento': 'Male',
#  'Dunma': 'Female',
#  'Finley': 'Female',
#  'Fronk': 'Male',
#  'Gaddison': 'unknown',
#  'Jiahto': 'unknown',
#  'Kayden': 'Male',
#  'Keye': 'Male',
#  'King_Dorephan': 'Male',
#  'Kodah': 'Female',
#  'Laflat': 'unknown',
#  'Laruta': 'Female',
#  'Marot': 'Female',
#  'Muzu': 'Male',
#  "Ne'ez_Yohma": 'unknown',
#  'Reagah': 'Male',
#  'Rivan': 'Male',
#  'Seggin': 'unknown',
#  'Trello': 'Male',
#  'Tumbo': 'Male',
#  'Shai_Yota': 'unknown',
#  'Ami': 'Male',
#  'Daka_Tuss': 'unknown',
#  'Izra': 'unknown',
#  'Kaya_Wan': 'unknown',
#  'Lawdon': 'unknown',
#  'Quince': 'Male',
#  'Satty': 'Male',
#  'Sheh_Rata': 'unknown',
#  'Yolero': 'unknown',
#  "Jitan_Sa'mi": 'unknown',
#  "Tahno_O'ah": 'unknown',
#  'Agus': 'Male',
#  'Celessa': 'Female',
#  'Garill': 'Male',
#  'Joute': 'Male',
#  'Letty': 'unknown',
#  'Spinch': 'unknown',
#  'Toma': 'Female',
#  'Calip': 'Male',
#  "Dow_Na'eh": 'unknown',
#  'Flavi': 'unknown',
#  'Garini': 'Male',
#  'Kah_Yah': 'unknown',
#  'Kam_Urog': 'unknown',
#  'Mimos': 'unknown',
#  'Muwo_Jeem': 'unknown',
#  'Perda': 'Female',
#  'Tawa_Jinn': 'unknown',
#  'Teli': 'Male',
#  'Wabbin': 'unknown',
#  'Amira': 'Female',
#  'Aster': 'Female',
#  'Azu': 'Male',
#  'Clavia': 'Female',
#  'Dantz': 'unknown',
#  'Horned_Statue': 'Male',
#  'Ivee': 'Female',
#  'Karin': 'unknown',
#  'Koyin': 'Female',
#  'Leop': 'Male',
#  'Manny': 'unknown',
#  'Medda': 'Male',
#  'Myahm_Agana': 'unknown',
#  'Nack': 'Male',
#  'Narah': 'Female',
#  'Nebb': 'Male',
#  'Nikki': 'Female',
#  'Prima': 'Female',
#  'Pruce': 'Male',
#  'Purah': 'Female',
#  'Ralera': 'Female',
#  'Reede': 'Male',
#  'Rhodes': 'Male',
#  'Sayge': 'Male',
#  'Sefaro': 'Male',
#  'Seldon': 'Male',
#  'Senna': 'Female',
#  'Sophie': 'Female',
#  'Symin': 'Male',
#  'Tamana': 'Female',
#  'Teebo': 'Male',
#  'Thadd': 'Male',
#  'Tokk': 'unknown',
#  'Uma': 'Female',
#  'Worten': 'Male',
#  'Armes': 'Male',
#  'Chessica': 'unknown',
#  'Cloyne': 'Male',
#  'Kiana': 'unknown',
#  'Kinov': 'unknown',
#  'Mubs': 'Female',
#  'Numar': 'Male',
#  'Rozel': 'unknown',
#  'Sebasto': 'unknown',
#  'Yah_Rin': 'unknown',
#  'Zuta': 'unknown',
#  'Chaas_Qeta': 'unknown',
#  'Korgu_Chideh': 'unknown',
#  'Mimo': 'Male',
#  'Anly': 'Male',
#  'Brokka': 'Female',
#  'Bugut': 'Male',
#  'Cima': 'unknown',
#  'Cotera': 'Female',
#  'Darton': 'Male',
#  'Domidak': 'Male',
#  'Giro': 'unknown',
#  'Ha_Dahamar': 'unknown',
#  'Hila_Rao': 'unknown',
#  'Hino': 'Male',
#  'Kampo': 'unknown',
#  'Magda': 'Female',
#  'Prissen': 'Male',
#  'Qukah_Nata': 'unknown',
#  'Ree_Dahee': 'unknown',
#  'Rensa': 'Male',
#  'Sagessa': 'Female',
#  'Shai_Utoh': 'unknown',
#  'Shay': 'Male',
#  'Shee_Vaneer': 'unknown',
#  'Shee_Venath': 'unknown',
#  'Shibo': 'Male',
#  'Shoda_Sah': 'unknown',
#  'Tasseren': 'Male',
#  'Toto_Sah': 'unknown',
#  'Cado': 'Male',
#  'Claree': 'Female',
#  'Cottla': 'Female',
#  'Dorian': 'Male',
#  'Impa': 'Female',
#  'Koko': 'Female',
#  'Lakna_Rokee': 'unknown',
#  'Lasli': 'Female',
#  'Mellie': 'Female',
#  'Nanna': 'Female',
#  'Olkin': 'Male',
#  'Ollie': 'Male',
#  'Paya': 'Female',
#  'Rola': 'Female',
#  'Steen': 'Male',
#  "Ta'loh_Naeg": 'unknown',
#  'Trissa': 'Female',
#  'Black_Bokoblin': 'unknown',
#  'Black_Lizalfos': 'unknown',
#  'Black_Moblin': 'unknown',
#  'Blizzrobe': 'unknown',
#  'Blue_Bokoblin': 'unknown',
#  'Blue_Lizalfos': 'unknown',
#  'Blue_Moblin': 'unknown',
#  'Bokoblin': 'unknown',
#  'Chuchu': 'unknown',
#  'Cursed_Bokoblin': 'unknown',
#  'Cursed_Lizalfos': 'unknown',
#  'Cursed_Moblin': 'unknown',
#  'Decayed_Guardian': 'unknown',
#  'Electric_Chuchu': 'unknown',
#  'Electric_Keese': 'unknown',
#  'Electric_Lizalfos': 'unknown',
#  'Electric_Wizzrobe': 'unknown',
#  'Fire_Chuchu': 'unknown',
#  'Fire_Keese': 'unknown',
#  'Fire_Wizzrobe': 'unknown',
#  'Forest_Octorok': 'unknown',
#  'Frost_Pebblit': 'unknown',
#  'Golden_Bokoblin': 'unknown',
#  'Golden_Lizalfos': 'unknown',
#  'Golden_Lynel': 'unknown',
#  'Golden_Moblin': 'unknown',
#  'Guardian_Stalker': 'unknown',
#  'Guardian_Scout_I': 'unknown',
#  'Guardian_Scout_II': 'unknown',
#  'Guardian_Scout_III': 'unknown',
#  'Guardian_Scout_IV': 'unknown',
#  'Guardian_Skywatcher': 'unknown',
#  'Guardian_Turret': 'unknown',
#  'Ice_Chuchu': 'unknown',
#  'Ice_Keese': 'unknown',
#  'Ice_Wizzrobe': 'unknown',
#  'Igneo_Pebblit': 'unknown',
#  'Keese': 'unknown',
#  'Lizalfos': 'unknown',
#  'Lynel': 'unknown',
#  'Meteo_Wizzrobe': 'unknown',
#  'Moblin': 'unknown',
#  'Rock_Octorok': 'unknown',
#  'Sentry': 'unknown',
#  'Silver_Bokoblin': 'unknown',
#  'Silver_Lizalfos': 'unknown',
#  'Silver_Lynel': 'unknown',
#  'Silver_Moblin': 'unknown',
#  'Sky_Octorok': 'unknown',
#  'Snow_Octorok': 'unknown',
#  'Stalizalfos': 'unknown',
#  'Stalkoblin': 'unknown',
#  'Stalmoblin': 'unknown',
#  'Stone_Pebblit': 'unknown',
#  'Thunder_Wizzrobe': 'unknown',
#  'Treasure_Octorok': 'unknown',
#  'Water_Octorok': 'unknown',
#  'Yiga_Blademaster': 'unknown',
#  'Yiga_Footsoldier': 'unknown',
#  'Stalnox': 'unknown',
#  'Windblight_Ganon': 'unknown',
#  'Molduking': 'unknown',
#  'Molduga': 'unknown',
#  'Thunderblight_Ganon': 'unknown',
#  'Igneo_Talus': 'unknown',
#  'Dark_Beast_Ganon': 'Male',
#  'Waterblight_Ganon': 'unknown',
#  'Frost_Talus': 'unknown',
#  'Monk_Maz_Koshia': 'Male',
#  'Hinox': 'unknown',
#  'Fireblight_Ganon': 'unknown',
#  'Stone_Talus': 'unknown',
#  'Blue_Hinox': 'unknown',
#  'Igneo_Talus_Titan': 'unknown',
#  'Black_Hinox': 'unknown'}

# %%
pattern1 = r'(?<=\[\[).*?(?=\]\])'
pattern2 = r'(?:Term|Plural)[\w\| \(\)\'\\\s\=]*(?=\})'

# %%
[print(re.split(r'\|', name)) for name in ['Term|BotW|Sheikah|link', 'Term|BotW|Perfect Dodging|link|display=Perfect Dodge|link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Sheikah|link', 'Term|BotW|Monk|link', 'Term|BotW|Main Quest|link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link|link', 'Term|BotW|Link', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Monk', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Sheikah Slate', 'Terminal|BotW', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Monk', 'Term|BotW|Monk', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Master Cycle Zero|link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Master Cycle Zero', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Sword', 'Term|BotW|Bow|link', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Monk', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Magnesis|link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Monk', 'Term|BotW|Hylian|link', 'Term|BotW|Champion|link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Monk', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Link', 'Term|BotW|Monk Maz Koshia', 'Term|BotW|Monk|link'] if len(re.split(r'\|', name)) > 2]
# Out:
# ['Term', 'BotW', 'Sheikah', 'link']
# ['Term', 'BotW', 'Perfect Dodging', 'link', 'display=Perfect Dodge', 'link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Sheikah', 'link']
# ['Term', 'BotW', 'Monk', 'link']
# ['Term', 'BotW', 'Main Quest', 'link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link', 'link']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Sheikah Slate']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk']
# ['Term', 'BotW', 'Monk']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Master Cycle Zero', 'link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Master Cycle Zero']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Sword']
# ['Term', 'BotW', 'Bow', 'link']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Monk']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Magnesis', 'link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Monk']
# ['Term', 'BotW', 'Hylian', 'link']
# ['Term', 'BotW', 'Champion', 'link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Monk']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Link']
# ['Term', 'BotW', 'Monk Maz Koshia']
# ['Term', 'BotW', 'Monk', 'link']
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
for char in df.name:#df.name:
    with open(f'characters/{char}.txt') as f:
        contents = f.read()
        links = []
        if re.findall(pattern2, contents):
            links += list(set([re.split(r'\|', name)[2] for name in re.findall(pattern2, contents) if len(re.split(r'\|', name)) > 2]))
        links += list(set([re.split(r'\#|\|', name)[0] for name in re.findall(pattern1, contents)]))
        links = [x.replace(" ", "_") for x in links]
        char_links = list(set(links) & set(df.name))
        
        for link in char_links:
            G.add_edge(char, link)

# %%
set(df.name)
# Out:
# {'Agus',
#  'Aji',
#  "Akh_Va'quot",
#  'Akrah',
#  'Aliza',
#  'Amali',
#  'Ami',
#  'Amira',
#  'Anche',
#  'Anly',
#  'Ardin',
#  'Ariane',
#  'Armes',
#  'Ashai',
#  'Ashe',
#  'Aster',
#  'Aurie_Taamu',
#  'Axyl',
#  'Aya',
#  'Azu',
#  'Babi',
#  'Baddek',
#  'Bamboo',
#  'Banji',
#  'Bareeda_Naag',
#  'Bargoh',
#  'Barta',
#  'Baumar',
#  'Bayge',
#  'Bazz',
#  'Bedoli',
#  'Beedle',
#  'Benja',
#  'Benny',
#  'Bertri',
#  'Black_Bokoblin',
#  'Black_Hinox',
#  'Black_Lizalfos',
#  'Black_Moblin',
#  'Bladon',
#  'Blizzrobe',
#  'Bludo',
#  'Blue_Bokoblin',
#  'Blue_Hinox',
#  'Blue_Lizalfos',
#  'Blue_Moblin',
#  'Blynne',
#  'Bohrin',
#  'Bokoblin',
#  'Boldon',
#  'Bolson',
#  'Bosh_Kala',
#  'Botrick',
#  'Bozai',
#  'Branli',
#  'Breen',
#  'Brigo',
#  'Brokka',
#  'Bugut',
#  'Buliara',
#  'Cado',
#  'Calamity_Ganon',
#  'Calip',
#  'Calisa',
#  'Calyban',
#  'Cambo',
#  'Canni',
#  'Canolo',
#  'Cara',
#  'Cecili',
#  'Celessa',
#  'Chaas_Qeta',
#  'Chabi',
#  'Cherry',
#  'Chessica',
#  'Chio',
#  'Chork',
#  'Chuchu',
#  'Chumin',
#  'Cima',
#  'Claree',
#  'Clavia',
#  'Cleff',
#  'Cloyne',
#  'Cotera',
#  'Cottla',
#  'Cree',
#  'Cursed_Bokoblin',
#  'Cursed_Lizalfos',
#  'Cursed_Moblin',
#  'Daag_Chokah',
#  'Dabi',
#  'Dagah_Keek',
#  'Dah_Hesho',
#  'Dah_Kaso',
#  'Dai',
#  'Daka_Tuss',
#  'Dako_Tah',
#  'Dalia',
#  'Damia',
#  'Danda',
#  'Danton',
#  'Dantz',
#  'Daqa_Koh',
#  'Daqo_Chisay',
#  'Dark_Beast_Ganon',
#  'Darton',
#  'Daruk',
#  'Dauntless',
#  'Dayto',
#  'Daz',
#  'Decayed_Guardian',
#  'Deltan',
#  'Dento',
#  'Dila_Maag',
#  'Dillie',
#  'Dina',
#  'Dinraal',
#  'Dmitri',
#  'Domidak',
#  'Dorian',
#  'Dorill',
#  'Dorrah',
#  'Douma',
#  "Dow_Na'eh",
#  'Drak',
#  'Dugby',
#  'Dunba_Taag',
#  'Dunma',
#  'Eighth_Heroine',
#  'Electric_Chuchu',
#  'Electric_Keese',
#  'Electric_Lizalfos',
#  'Electric_Wizzrobe',
#  'Emri',
#  'Ena',
#  'Endai',
#  'Epona',
#  'Eryck',
#  'Essa',
#  'Estan',
#  'Etsu_Korima',
#  'Falmark',
#  'Farosh',
#  'Fegran',
#  'Fin',
#  'Finley',
#  'Fire_Chuchu',
#  'Fire_Keese',
#  'Fire_Wizzrobe',
#  'Fireblight_Ganon',
#  'Flavi',
#  'Flaxel',
#  'Forest_Octorok',
#  'Frelly',
#  'Frita',
#  'Fronk',
#  'Frost_Pebblit',
#  'Frost_Talus',
#  'Fugo',
#  'Furosa',
#  'Fyson',
#  'Gaddison',
#  'Gaile',
#  'Galli',
#  'Garill',
#  'Garini',
#  'Garshon',
#  'Gartan',
#  "Gee_Ha'rah",
#  'Geggle',
#  'Genli',
#  'Gesane',
#  'Giro',
#  'Gleema',
#  'Glendo',
#  'Goflam',
#  'Golden_Bokoblin',
#  'Golden_Lizalfos',
#  'Golden_Lynel',
#  'Golden_Moblin',
#  'Goma_Asaagh',
#  'Gonguron',
#  'Gorae_Torr',
#  'Gotter',
#  'Grapp',
#  'Greta',
#  'Greyson',
#  'Gruve',
#  'Guardian_Scout_I',
#  'Guardian_Scout_II',
#  'Guardian_Scout_III',
#  'Guardian_Scout_IV',
#  'Guardian_Skywatcher',
#  'Guardian_Stalker',
#  'Guardian_Turret',
#  'Guy',
#  'Ha_Dahamar',
#  'Hagie',
#  'Haite',
#  'Harlow',
#  'Harry',
#  'Harth',
#  'Hawa_Koth',
#  'Heehl',
#  'Hestu',
#  'Hia_Miu',
#  'Hila_Rao',
#  'Hino',
#  'Hinox',
#  'Horned_Statue',
#  'Hoz',
#  'Huck',
#  'Hudson',
#  'Hunnie',
#  'Hylia',
#  'Ice_Chuchu',
#  'Ice_Keese',
#  'Ice_Wizzrobe',
#  'Igneo_Pebblit',
#  'Igneo_Talus',
#  'Igneo_Talus_Titan',
#  'Impa',
#  'Isha',
#  'Ishto_Soh',
#  'Ivee',
#  'Izra',
#  'Ja_Baij',
#  'Jana',
#  'Jee_Noh',
#  'Jengo',
#  'Jerrin',
#  'Jiahto',
#  'Jini',
#  "Jitan_Sa'mi",
#  'Jogo',
#  'Joloo_Nah',
#  'Jora',
#  'Joute',
#  'Juannelle',
#  'Jules',
#  'Juney',
#  "Ka'o_Makagh",
#  "Kaam_Ya'tak",
#  'Kabetta',
#  'Kachoo',
#  'Kah_Mael',
#  'Kah_Okeo',
#  'Kah_Yah',
#  'Kaifa',
#  'Kairo',
#  'Kalani',
#  'Kam_Urog',
#  'Kampo',
#  'Kaneli',
#  'Kanny',
#  'Kapson',
#  'Karin',
#  'Karsh',
#  'Karson',
#  'Kass',
#  'Katah_Chuki',
#  'Katosa_Aug',
#  'Katta',
#  'Kay_Noh',
#  'Kaya_Wan',
#  'Kayden',
#  'Kayra_Mah',
#  'Kaysa',
#  "Ke'nai_Shakah",
#  'Keeha_Yoog',
#  'Keese',
#  'Keh_Namut',
#  'Keive_Tala',
#  'Kema_Kosassa',
#  'Kema_Zoos',
#  'Kenyo',
#  'Keo_Ruug',
#  'Ketoh_Wawai',
#  'Keye',
#  'Kheel',
#  'Khini',
#  'Kiah_Toza',
#  'Kiana',
#  'Kihiro_Moh',
#  'Kilton',
#  'Kima',
#  'King_Dorephan',
#  'King_Rhoam',
#  'Kinov',
#  'Kish',
#  'Kodah',
#  'Kohm',
#  'Koko',
#  'Konba',
#  'Konora',
#  'Korgu_Chideh',
#  "Korsh_O'hu",
#  'Kotta',
#  'Kotts',
#  'Koyin',
#  'Krane',
#  'Kuh_Takkar',
#  'Kuhn_Sidajj',
#  'Kula',
#  'Kyra',
#  'Laflat',
#  'Laine',
#  'Laissa',
#  'Lakna_Rokee',
#  'Lanno_Kooh',
#  'Laroba',
#  'Laruta',
#  'Lashley',
#  'Lasli',
#  'Lawdon',
#  'Ledo',
#  'Leekah',
#  'Leena',
#  'Leop',
#  'Lester',
#  'Letty',
#  'Liana',
#  'Link',
#  'Lizalfos',
#  'Lonni',
#  'Loone',
#  'Lorn',
#  'Lukan',
#  'Lyndae',
#  'Lynel',
#  'Maag_Halan',
#  "Maag_No'rah",
#  'Maca',
#  'Magda',
#  'Maike',
#  'Maka_Rah',
#  'Makure',
#  'Malanya',
#  'Malena',
#  'Manny',
#  'Marot',
#  'Marta',
#  'Mary',
#  'Master_Kohga',
#  'Maypin',
#  'Mayro',
#  'Mazli',
#  'Medda',
#  'Meeshy',
#  'Meghyn',
#  'Mei',
#  'Mellie',
#  'Merina',
#  'Meteo_Wizzrobe',
#  'Mezza_Lo',
#  'Mijah_Rokee',
#  'Mils',
#  'Mimo',
#  'Mimos',
#  'Mina',
#  'Mipha',
#  'Mirro_Shaz',
#  'Misa',
#  'Misae_Suma',
#  'Misko',
#  "Mo'a_Keet",
#  'Moblin',
#  'Modar',
#  'Mogg_Latan',
#  'Moggs',
#  'Molduga',
#  'Molduking',
#  'Molli',
#  'Molo',
#  'Monari',
#  'Monk_Maz_Koshia',
#  'Monkton',
#  'Monya_Toma',
#  'Moza',
#  'Mozo_Shenno',
#  'Muava',
#  'Mubs',
#  'Muwo_Jeem',
#  'Muzu',
#  'Myahm_Agana',
#  'Myti',
#  'Nack',
#  'Naddon',
#  'Nali',
#  'Namika_Ozz',
#  'Nanna',
#  'Narah',
#  'Nat',
#  'Natie',
#  'Naydra',
#  'Nazbi',
#  "Ne'ez_Yohma",
#  'Nebb',
#  'Nekk',
#  'Nell',
#  'Nellie',
#  'Nikki',
#  'Nobiro',
#  'Nobo',
#  'Noe_Rajee',
#  'Notts',
#  'Noya_Neha',
#  'Numar',
#  'Oaki',
#  'Offrak',
#  'Old_Man',
#  'Oliff',
#  'Olkin',
#  'Ollie',
#  'Olu',
#  'Oman_Au',
#  'Onya',
#  'Owa_Daim',
#  'Ozunda',
#  'Padda',
#  'Padok',
#  'Palme',
#  'Parcy',
#  'Pasha',
#  'Patricia',
#  'Paya',
#  'Pearle',
#  'Peeks',
#  'Pelison',
#  'Pepp',
#  'Perda',
#  'Perosa',
#  'Phanna',
#  'Piaffe',
#  'Pikango',
#  'Pirou',
#  'Pitar',
#  'Ploka',
#  'Pokki',
#  'Pondo',
#  'Ponthos',
#  'Prima',
#  'Princess_Zelda',
#  'Prissen',
#  'Pritana',
#  'Pruce',
#  'Pumaag_Nitae',
#  'Purah',
#  'Pyle',
#  'Pyra',
#  'Qaza_Tokki',
#  'Qua_Raym',
#  'Quince',
#  'Qukah_Nata',
#  'Ralera',
#  'Ramella',
#  'Raqa_Zunzo',
#  'Reagah',
#  'Ree_Dahee',
#  'Reede',
#  'Reeza',
#  'Regan',
#  'Rensa',
#  'Revali',
#  'Rex',
#  'Rhodes',
#  'Rhondson',
#  'Riju',
#  'Rik',
#  'Rima',
#  'Rin_Oyaa',
#  'Ripp',
#  'Risa',
#  'Ritaag_Zumo',
#  'Rivan',
#  'Robbie',
#  'Robsten',
#  'Rock_Octorok',
#  'Rogaro',
#  'Rohan',
#  'Rohta_Chigah',
#  'Rok_Uwog',
#  'Rola',
#  'Romah',
#  'Rona_Kachta',
#  'Ronn',
#  'Roscoe',
#  'Rota_Ooh',
#  'Rotana',
#  'Rozel',
#  'Rucco_Maag',
#  'Rudi',
#  'Ruli',
#  'Russ',
#  'Ruvo_Korbah',
#  "Saas_Ko'sah",
#  'Sagessa',
#  'Sah_Dahaj',
#  'Saki',
#  'Sasa_Kai',
#  'Satty',
#  'Saula',
#  'Savelle',
#  'Sayge',
#  'Sebasto',
#  'Sefaro',
#  'Seggin',
#  'Seldon',
#  'Selmie',
#  'Senna',
#  'Sentry',
#  'Sesami',
#  'Seven_Heroines',
#  'Sha_Gehma',
#  'Sha_Warvo',
#  'Shabonne',
#  'Shada_Naw',
#  'Shae_Katha',
#  'Shae_Loya',
#  "Shae_Mo'sah",
#  'Shai_Utoh',
#  'Shai_Yota',
#  'Shaillu',
#  'Shamae',
#  'Shay',
#  'Shee_Vaneer',
#  'Shee_Venath',
#  'Sheem_Dagoze',
#  'Sheh_Rata',
#  'Sherfin',
#  'Shibo',
#  'Shira_Gomar',
#  'Sho',
#  'Sho_Dantu',
#  'Shoda_Sah',
#  'Shoqa_Tatone',
#  'Shora_Hah',
#  'Sidon',
#  'Silver_Bokoblin',
#  'Silver_Lizalfos',
#  'Silver_Lynel',
#  'Silver_Moblin',
#  'Sky_Octorok',
#  'Slergo',
#  'Smaude',
#  'Snow_Octorok',
#  'Soh_Kofi',
#  'Sophie',
#  'Sorelia',
#  'Spera',
#  'Spinch',
#  'Spoone',
#  'Sprinn',
#  'Stalizalfos',
#  'Stalkoblin',
#  'Stalmoblin',
#  'Stalnox',
#  'Stamm',
#  'Steen',
#  'Stone_Pebblit',
#  'Stone_Talus',
#  'Strade',
#  'Straia',
#  'Sudrey',
#  'Suma_Sahma',
#  'Sumati',
#  'Suzuna',
#  'Symin',
#  "Ta'loh_Naeg",
#  'Tah_Muhl',
#  "Tahno_O'ah",
#  'Takama_Shiri',
#  'Tali',
#  'Tamana',
#  'Tanko',
#  'Tasho',
#  'Tasseren',
#  'Tauma',
#  'Tawa_Jinn',
#  'Teake',
#  'Teba',
#  'Teebo',
#  'Teli',
#  "Tena_Ko'sah",
#  'Tenne',
#  'Tera',
#  'Thadd',
#  'The_Great_Deku_Tree',
#  'Tho_Kayu',
#  'Thunder_Wizzrobe',
#  'Thunderblight_Ganon',
#  'To_Quomo',
#  'Toffa',
#  'Toh_Yahsa',
#  'Tokk',
#  'Toma',
#  'Tona',
#  'Toren',
#  'Torfeau',
#  'Toto_Sah',
#  'Totsuna',
#  'Tottika',
#  'Tray',
#  'Traysi',
#  'Treasure_Octorok',
#  'Trello',
#  'Trissa',
#  'Trott',
#  "Tu_Ka'loh",
#  'Tula',
#  'Tulin',
#  'Tumbo',
#  'Tutsuwa_Nima',
#  'Tye',
#  'Uma',
#  'Urbosa',
#  'Varke',
#  'Verla',
#  'Vilia',
#  'Volcon',
#  'Voo_Lota',
#  'Wabbin',
#  'Wahgo_Katta',
#  'Walton',
#  'Water_Octorok',
#  'Waterblight_Ganon',
#  'Windblight_Ganon',
#  'Worten',
#  'Ya_Naga',
#  'Yah_Rin',
#  'Yaido',
#  'Yammo',
#  'Yiga_Blademaster',
#  'Yiga_Footsoldier',
#  'Yolero',
#  'Yowaka_Ita',
#  'Yunobo',
#  'Zalta_Wa',
#  'Ze_Kasho',
#  'Zooki',
#  'Zorona',
#  'Zumi',
#  'Zuna_Kai',
#  'Zuta',
#  'Zyle'}

# %%
links
# Out:
# ["Martha's_Landing",
#  'Lake_Hylia_North',
#  'Kolami_Bridge_South',
#  'Upland_Lindor',
#  'Bomb_Arrow',
#  'Link',
#  'West_Vatorsa_Snowfield',
#  'Obsidian_Talus',
#  'Frost_Talus',
#  'Dueling_Peaks_South',
#  'Illumeni_Plateau',
#  'Stone_Talus_(Luminous)',
#  'Remote_Bomb',
#  'Gama_Cove',
#  'Igneo_Talus_Titan',
#  'Stone_Pebblit',
#  'South_Taafei_Hill',
#  'Heart',
#  'Cliffs_of_Quince',
#  'Deya_Lake',
#  'Stone_Talus_(Junior)',
#  'Hyrule_Castle_West',
#  'Igneo_Talus',
#  'Ovli_Plain',
#  'Ore_Deposit',
#  'Hyrule_Castle_Underground',
#  'Rutimala_Hill',
#  'Hyrule',
#  'North_Mable_Ridge',
#  'Iron_Sledgehammer',
#  'Amber',
#  'West_Nabi_Lake',
#  'Lake_Kolomo',
#  'Hyrule_Kingdom',
#  "Champion's_Gate_North",
#  'Enemy',
#  'Heart_Container',
#  'Gem',
#  'Stone_Talus_(Rare)',
#  'Lake_Floria',
#  'Weapon',
#  'Great_Plateau',
#  'Sandstone_Talus',
#  'South_Koukot_Plateau',
#  'Southern_Tal_Tal_Peak',
#  'North_Dueling_Peaks',
#  'Stone_Talus_(Senior)',
#  'Ruby',
#  'Tabantha_Hills',
#  'Monster_Stronghold',
#  'East_Mount_Granajh',
#  'Stone_Talus',
#  'Opal',
#  'Mapla_Point',
#  'Mount_Nabooru',
#  'Crenel_Hills',
#  'Gisa_Crater',
#  '',
#  'de:Iwarok',
#  'zh-tw:\\u5ca9\\u77f3\\u5de8\\u4eba',
#  'Destroy_Ganon',
#  'Kilton',
#  'Flint',
#  'Medal_of_Honor:_Talus',
#  'fr:Lithorok',
#  'es:Petrarok',
#  'Main_Quest']

# %%
df.name
# Out:
# 0                 Baddek
# 1                 Bamboo
# 2                  Banji
# 3                 Baumar
# 4                  Bayge
#              ...
# 645          Stone_Talus
# 646           Blue_Hinox
# 647    Igneo_Talus_Titan
# 648          Black_Hinox
# 649          Stone_Talus
# Name: name, Length: 649, dtype: object

# %%
contents
# Out:
# '{"batchcomplete":"","query":{"normalized":[{"from":"Princess_Zelda","to":"Princess Zelda"}],"pages":{"970":{"pageid":970,"ns":0,"title":"Princess Zelda","revisions":[{"slots":{"main":{"contentmodel":"wikitext","contentformat":"text/x-wiki","*":":\'\'This article is about the eponymous character of {{TLoZ|-}} franchise. For the video-game series named after her, see {{TLoZ|Series}}. For other uses, see [[Zelda (disambiguation)]]. \\n{{Infobox Character\\n|image= \\n{{Media\\n |Artwork TLoZ= File:TLoZ Princess Zelda Artwork.png\\n |Artwork TAoL= File:TAoL Princess Zelda and Prince of Hyrule Artwork.png\\n |Artwork ALttP= File:Link To The Past Remake - Princess Zelda.png\\n |Artwork OoT= File:OoT Adult Zelda Artwork.png\\n |Artwork OoT3D= File:Young Princess Zelda OoT3D.png\\n |Artwork OoS= File:OoS Zelda Artwork.png\\n |Artwork OoA= File:OoA Zelda Artwork.png\\n |Artwork FS= File:FS Princess Zelda Artwork.png\\n |Artwork TWW= File:TWW Princess Zelda Artwork.png\\n |Artwork TWWHD= File:TWWHD Princess Zelda Artwork.png\\n |Artwork TMC= File:TMC Princess Zelda Artwork.png\\n |Artwork TPHD= File:TPHD Zelda Artwork.png\\n |Artwork ST= File:ST Princess Zelda Artwork.png\\n |Artwork SS= File:SS Zelda Artwork.png\\n |Artwork ALBW= File:ALBW Princess Zelda Artwork.png\\n |Artwork BotW= File:BotW Zelda Artwork.png\\n |Render OoT3D= File:OoT3D Young Princess Zelda Render.png\\n |Render TP= File:TP Princess Zelda Render.png\\n |Model OoT= File:OoT Princess Zelda Model.png\\n |Model OoT3D= File:OoT3D Princess Zelda Model.png\\n |Model MM= File:MM Princess Zelda Model.png\\n |Model MM3D= File:MM3D Princess Zelda Model.png\\n |Model TWW= File:TWW Princess Zelda Figurine Model.png\\n |Model TWWHD= File:TWWHD Princess Zelda Figurine Model.png\\n |Model TP= File:TP Princess Zelda Robed Model.png\\n |Model TPHD= File:TPHD Princess Zelda Model.png\\n |Model ST= File:ST Princess Zelda Model 2.png\\n |Model SS= File:SS Zelda Model.png\\n |Model SSHD= File:SSHD Zelda Model.png\\n |Model ALBW= File:ALBW Princess Zelda Model.png\\n |Model BotW= File:BotW Zelda Model 3.png\\n |Model StBotW= File:StBotW Zelda.png\\n |Sprite TLoZ= File:TLoZ Princess Zelda Sprite.png\\n |Sprite TAoL= File:TAoL Princess Zelda Awoken Sprite.png\\n |Sprite ALttP= File:ZeldaALttPDungeon.png\\n |Sprite OoS= File:OoS Zelda Sprite.png\\n |Sprite OoA= File:OoA Zelda Sprite.png\\n |Sprite FS= File:FS Princess Zelda Sprite.png\\n |Sprite FSA= File:FSA Princess Zelda Sprite.png\\n |Sprite TMC= File:TMC Princess Zelda Sprite.png\\n |Sprite SS= File:SS Zelda Icon.png\\n |Sprite SSHD= File:SSHD Zelda Icon.png\\n}}\\n|caption= \\n|pronunciation= {{IPA|\\u02c8z\\u025bld\\u0259}} {{respell|ZEL|d\\u0259}}<ref>{{Cite|Zelda|Announcer|SSBB}}</ref>\\n|title= \\n{{Infobox Game Blocks\\n |Series= Princess of Legend<ref name=\\"E 16\\">{{Cite Book|quote= |book= E |publisher= |page= 16}}</ref>\\n |TAoL= Ancient Princess<ref name=\\"E 17\\">{{Cite Book|quote= |book= E |publisher= |page= 17}}</ref>\\n |ALttP= Princess of Light<ref>{{Cite Book|quote= |book= HH |publisher= |page= 94 }}</ref><br>Triforce Guide<ref name=\\"E 16\\"/>\\n |OoT= Princess of Hyrule<ref name=\\"Seventh Sage\\">{{Cite|And the other, who holds the Triforce of Wisdom...is the seventh Sage, who is destined to be the leader of them all... It is I, the Princess of Hyrule, Zelda.|Princess Zelda|OoT}}</ref><br>Princess of Destiny<ref name=\\"Destiny\\">{{Cite|Link... Go now to Hyrule Castle... There, thou will surely meet the Princess of Destiny...|Great Deku Tree|OoT}}</ref><br>Master of Disguise Who Manipulates Time<ref name=\\"E 16\\"/>\\n |OoS= Holy Sacrifice<ref>{{Cite|The Flames of Sorrow, Destruction and Despair burn brightly. The return of the Evil King {{Color|OoS Blue|Ganon}} approaches. The Holy Sacrifice, {{Color|OoS Blue|Zelda}}, is all that remains! When we call {{Color|OoS Blue|Ganon\'s}} spirit into the vessel, it will be done! You can\'t stop us! Prepare to meet your doom!|Twinrova|OoS}}</ref><br>Hope of Her People<re ...

# %%
char_links
# Out:
# ['Stone_Talus',
#  'Frost_Talus',
#  'Igneo_Talus_Titan',
#  'Kilton',
#  'Link',
#  'Igneo_Talus',
#  'Stone_Pebblit']

# %%
re.findall(pattern1, contents)
# Out:
# ['#Locations|below',
#  'Flint',
#  'Medal of Honor: Talus',
#  'Kilton',
#  'Destroy Ganon',
#  'Main Quest',
#  'de:Iwarok',
#  'es:Petrarok',
#  'fr:Lithorok',
#  'zh-tw:\\u5ca9\\u77f3\\u5de8\\u4eba']

# %%
print(links)
# Out:
# ["Martha's_Landing", 'Lake_Hylia_North', 'Kolami_Bridge_South', 'Upland_Lindor', 'Bomb_Arrow', 'Link', 'West_Vatorsa_Snowfield', 'Obsidian_Talus', 'Frost_Talus', 'Dueling_Peaks_South', 'Illumeni_Plateau', 'Stone_Talus_(Luminous)', 'Remote_Bomb', 'Gama_Cove', 'Igneo_Talus_Titan', 'Stone_Pebblit', 'South_Taafei_Hill', 'Heart', 'Cliffs_of_Quince', 'Deya_Lake', 'Stone_Talus_(Junior)', 'Hyrule_Castle_West', 'Igneo_Talus', 'Ovli_Plain', 'Ore_Deposit', 'Hyrule_Castle_Underground', 'Rutimala_Hill', 'Hyrule', 'North_Mable_Ridge', 'Iron_Sledgehammer', 'Amber', 'West_Nabi_Lake', 'Lake_Kolomo', 'Hyrule_Kingdom', "Champion's_Gate_North", 'Enemy', 'Heart_Container', 'Gem', 'Stone_Talus_(Rare)', 'Lake_Floria', 'Weapon', 'Great_Plateau', 'Sandstone_Talus', 'South_Koukot_Plateau', 'Southern_Tal_Tal_Peak', 'North_Dueling_Peaks', 'Stone_Talus_(Senior)', 'Ruby', 'Tabantha_Hills', 'Monster_Stronghold', 'East_Mount_Granajh', 'Stone_Talus', 'Opal', 'Mapla_Point', 'Mount_Nabooru', 'Crenel_Hills', 'Gisa_Crater', '', 'de:Iwarok', 'zh-tw:\\u5ca9\\u77f3\\u5de8\\u4eba', 'Destroy_Ganon', 'Kilton', 'Flint', 'Medal_of_Honor:_Talus', 'fr:Lithorok', 'es:Petrarok', 'Main_Quest']

# %%
G.nodes
# Out:
# NodeView(('Baddek', 'Bamboo', 'Banji', 'Baumar', 'Bayge', 'Beedle', 'Bolson', 'Brigo', 'Cambo', 'Chabi', 'Chork', 'Chumin', 'Dabi', 'Daruk', 'Dauntless', 'Dinraal', 'Ena', 'Endai', 'Epona', 'Farosh', 'Fyson', 'Goflam', 'Greyson', 'Heehl', 'Hestu', 'Hudson', 'Hylia', 'Kabetta', 'Kanny', 'Kapson', 'Karson', 'Kass', 'Kenyo', 'Kilton', 'Leekah', 'Link', 'Meeshy', 'Meghyn', 'Mei', 'Mils', 'Mina', 'Mipha', 'Misko', 'Nat', 'Naydra', 'Nazbi', 'Pelison', 'Pikango', 'Regan', 'Revali', 'Rhondson', 'Rik', 'Ronn', 'Savelle', 'Sherfin', 'Sho', 'Sorelia', 'Spoone', 'Toren', 'Totsuna', 'Tye', 'Urbosa', 'Yammo', 'Princess_Zelda', 'Zyle', 'Laroba', 'Naddon', 'Pitar', 'Dah_Hesho', 'Dmitri', 'Gleema', 'Jana', 'Kah_Mael', 'Kaifa', "Ke'nai_Shakah", 'Lonni', 'Nell', 'Rex', 'Stamm', 'Tenne', 'Tutsuwa_Nima', 'Ze_Kasho', 'Hagie', 'Hunnie', 'Moggs', 'Monari', 'Ruli', 'Ritaag_Zumo', "Tu_Ka'loh", 'Aya', 'Cherry', 'Hoz', 'Jerrin', 'Katosa_Aug', 'Khini', 'Nobo', 'Robbie', 'Rudi', 'Zuna_Kai', 'Glendo', 'King_Rhoam', 'Etsu_Korima', 'Ja_Baij', 'Keh_Namut', 'Old_Man', 'Oman_Au', 'Owa_Daim', 'Rohta_Chigah', 'Ruvo_Korbah', 'Yowaka_Ita', 'Aliza', 'Benny', 'Bosh_Kala', 'Botrick', 'Calamity_Ganon', 'Canni', 'Dah_Kaso', 'Dai', 'Gotter', 'Haite', "Kaam_Ya'tak", 'Katah_Chuki', 'Monya_Toma', 'Myti', 'Namika_Ozz', 'Noya_Neha', 'Parcy', 'Rota_Ooh', "Saas_Ko'sah", 'Toffa', 'Trott', 'Wahgo_Katta', 'Zalta_Wa', 'Branli', 'Konba', "Maag_No'rah", 'Mijah_Rokee', 'Mogg_Latan', 'Shira_Gomar', 'Toh_Yahsa', 'Yunobo', 'Ashe', 'Axyl', 'Bladon', 'Bohrin', 'Boldon', 'Breen', 'Daqa_Koh', 'Dayto', 'Dorill', 'Douma', 'Drak', 'Dugby', 'Fin', 'Gaile', 'Gonguron', 'Gorae_Torr', 'Grapp', 'Jengo', 'Kairo', 'Karsh', 'Kayra_Mah', 'Kima', 'Kish', 'Mayro', 'Mirro_Shaz', "Mo'a_Keet", 'Molo', 'Offrak', 'Ozunda', 'Qua_Raym', 'Russ', 'Sah_Dahaj', 'Shamae', 'Shora_Hah', 'Tah_Muhl', 'Zorona', 'Aji', 'Bargoh', 'Bludo', 'Fugo', 'Krane', 'Pyle', 'Ramella', 'Rogaro', 'Rohan', "Shae_Mo'sah", 'Slergo', 'Tanko', 'Tray', 'Volcon', 'Akrah', 'Daag_Chokah', 'Garshon', 'Ketoh_Wawai', 'Kuhn_Sidajj', 'Maag_Halan', 'Oaki', 'Onya', 'Sprinn', 'Tasho', 'Zooki', 'Zumi', 'Chio', 'Damia', 'Daz', 'Keo_Ruug', 'Kula', 'Maca', 'Natie', 'Peeks', 'Pepp', 'The_Great_Deku_Tree', 'Walton', 'Blynne', 'Jini', "Ka'o_Makagh", 'Loone', 'Malanya', 'Padok', 'Perosa', 'Phanna', 'Pumaag_Nitae', 'Roscoe', 'Shae_Katha', 'Shoqa_Tatone', 'Straia', 'Suzuna', 'Ya_Naga', 'Barta', 'Calisa', 'Eighth_Heroine', 'Gartan', 'Lukan', 'Seven_Heroines', 'Anche', 'Benja', 'Dako_Tah', 'Daqo_Chisay', 'Dila_Maag', 'Dillie', 'Hawa_Koth', 'Jee_Noh', 'Jora', 'Kay_Noh', 'Keive_Tala', 'Kema_Zoos', 'Konora', "Korsh_O'hu", 'Kyra', 'Misae_Suma', 'Patricia', 'Pokki', 'Raqa_Zunzo', 'Riju', 'Shabonne', 'Strade', 'Sudrey', 'Takama_Shiri', 'Tali', 'Tera', 'Tho_Kayu', 'Ardin', 'Ashai', 'Aurie_Taamu', 'Babi', 'Bertri', 'Bozai', 'Buliara', 'Calyban', 'Cara', 'Dalia', 'Danda', 'Deltan', 'Dina', 'Dorrah', 'Essa', 'Estan', 'Fegran', 'Frelly', 'Frita', 'Furosa', 'Greta', 'Isha', 'Jules', 'Kalani', 'Katta', 'Kohm', 'Kotta', 'Laine', 'Lashley', 'Leena', 'Liana', 'Lorn', 'Lyndae', 'Makure', 'Malena', 'Marta', 'Merina', 'Muava', 'Nali', 'Nellie', 'Olu', 'Padda', 'Pasha', 'Pearle', 'Ploka', 'Pritana', 'Pyra', 'Reeza', 'Rima', 'Risa', 'Romah', 'Rotana', 'Saula', 'Smaude', 'Spera', 'Sumati', 'Tauma', 'Teake', 'Traysi', 'Yaido', 'Emri', 'Guy', 'Kachoo', 'Maike', 'Nobiro', 'Ripp', 'Robsten', 'Shaillu', 'Vilia', 'Canolo', 'Flaxel', 'Ishto_Soh', 'Joloo_Nah', 'Keeha_Yoog', 'Kema_Kosassa', 'Kihiro_Moh', 'Kuh_Takkar', 'Master_Kohga', 'Maypin', 'Moza', 'Oliff', 'Palme', 'Piaffe', 'Pirou', 'Sasa_Kai', 'Sesami', 'Sho_Dantu', 'Suma_Sahma', 'Falmark', 'Teba', 'Tulin', 'Goma_Asaagh', 'Hia_Miu', 'Kiah_Toza', 'Maka_Rah', 'Mozo_Shenno', 'Noe_Rajee', 'Qaza_Tokki', 'Rok_Uwog', 'Selmie', 'Sha_Warvo', 'Shada_Naw', 'To_Quomo', 'Danton', 'Harlow', 'Harry', 'Juannelle', 'Mary', 'Monkton', 'Rin_Oyaa', 'Sha_Gehma', 'Varke', 'Ariane', 'Bareeda_Naag', 'Cree', 'Dunba_Taag', 'Galli', "Gee_Ha'rah", 'Geggle', 'Genli', ' ...

# %%
list(G.neighbors('Princess_Zelda'))
# Out:
# ['Link',
#  'Impa',
#  'Kass',
#  'Hylia',
#  'Daruk',
#  'Princess_Zelda',
#  'Yiga_Footsoldier',
#  'King_Rhoam']

# %% [markdown]
# > *Exercise 2*: Simple network statistics and analysis
# >
# > * What is the number of nodes in the network?
# > * More importantly, what is the number of links?
# > * Plot the distributions of Role, Race, and Gender.
# > * Plot the total (in+out), in and out-degree distributions. What do you observe? Can you explain why the in-degree distribution is different from the out-degree distribution?
# >     * Compare the degree distribution to a *random network* with the same number of nodes and *p*
# >     * Compare the degree distribution to a *scale-free* network with the same number of nodes.
# > * Who is the top connected character in BotW? (Report results for the undirected network, in-degrees and out-degrees). Comment on your findings. Is this what you would have expected?
# > * Who are the top 5 most connected allies (again in terms of all edges, and in/out-degree)?
# > * Who are the top 5 most connected enemies -- bosses included -- (again in terms of all edges in/out-degree)?

# %% [markdown]
# > The total degree distribution (in + out degree) for you network should resemble the distribution displayed on the image below *(`Isolated` means that we have discarded the nodes with zero degrees)*:
# ![img](https://github.com/SocialComplexityLab/socialgraphs2021/blob/main/files/week4_degrees.png?raw=true)
# > *Tip:* If you want your `matplotlib` plots to look like the one above, you can download the `seaborn` package and do the following: `import seaborn as sns
# sns.set()`

# %%
len(G)
# Out:
# 646

# %%
len(G.edges)
# Out:
# 1893

# %%
roles = [G.nodes[node]['role'] for node in G.nodes]
genders = [G.nodes[node]['gender'] for node in G.nodes]
races = [G.nodes[node]['race'] for node in G.nodes]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.hist(roles)
plt.show()

# %%
pd.Series(roles).value_counts()
# Out:
# ally     569
# enemy     59
# boss      18
# dtype: int64

# %%
plt.hist(genders)
plt.show()

# %%
pd.Series(genders).value_counts()
# Out:
# unknown    311
# Male       171
# Female     163
# Unknown      1
# dtype: int64

# %%
plt.figure(figsize=(16,8))
plt.hist(races, bins = len(set(races)))
plt.show()

# %%
pd.Series(races).value_counts()
# Out:
# Hylian            200
# unknown           150
# Sheikah            80
# Gerudo             74
# Goron              36
# Zora               27
# Rito               26
# Korok              13
# Lizalfos            6
# Bokoblin            5
# Octorok             4
# Guardian Scout      3
# Chuchu              3
# Great               2
# Igneo               2
# Moblin              2
# Keese               2
# Horse               2
# Wizzrobe            2
# Frost               1
# Molduga             1
# Stone               1
# Great Fairy         1
# Ancient Orb         1
# Dog                 1
# Lynel               1
# dtype: int64

# %%
import numpy as np
x = [val for (node, val) in G.degree() if val != 0]
counts, edges = np.histogram(x, bins = 100)
plt.bar(edges[:-1], counts, width=np.diff(edges))
plt.title("Degree distribution of graph G_np")
plt.xlabel('Number of nodes')
plt.ylabel('Degree of the node')
plt.show()

# %%
x = [val for (node, val) in G.degree() if val != 0]
counts, edges = np.histogram(x, bins = 1000)
plt.scatter(np.log(edges[:-1]), np.log(counts))
plt.title("Degree distribution of graph G_np")
plt.xlabel('Number of nodes')
plt.ylabel('Degree of the node')
plt.show()
# Out:
# <ipython-input-160-a6582b2e7449>:3: RuntimeWarning: divide by zero encountered in log
#   plt.scatter(np.log(edges[:-1]), np.log(counts))

# %%
import numpy as np
x = [val for (node, val) in G.in_degree() if val != 0]
counts, edges = np.histogram(x, bins = 100)
plt.bar(edges[:-1], counts, width=np.diff(edges))
plt.title("Degree distribution of graph G_np")
plt.xlabel('Number of nodes')
plt.ylabel('Degree of the node')
plt.show()

# %%
counts, edges = np.histogram(x, bins = 1000)
plt.scatter(np.log(edges[:-1]), np.log(counts))
plt.title("Degree distribution of graph G_np")
plt.xlabel('Number of nodes')
plt.ylabel('Degree of the node')
plt.show()
# Out:
# <ipython-input-162-caa18d6edb39>:2: RuntimeWarning: divide by zero encountered in log
#   plt.scatter(np.log(edges[:-1]), np.log(counts))

# %%
import numpy as np
x = [val for (node, val) in G.out_degree() if val != 0]
counts, edges = np.histogram(x, bins = 100)
plt.bar(edges[:-1], counts, width=np.diff(edges))
plt.title("Degree distribution of graph G_np")
plt.xlabel('Number of nodes')
plt.ylabel('Degree of the node')
plt.show()

# %%
counts, edges = np.histogram(x, bins = 1000)
plt.scatter(np.log(edges[:-1]), np.log(counts))
plt.title("Degree distribution of graph G_np")
plt.xlabel('Number of nodes')
plt.ylabel('Degree of the node')
plt.show()
# Out:
# <ipython-input-163-caa18d6edb39>:2: RuntimeWarning: divide by zero encountered in log
#   plt.scatter(np.log(edges[:-1]), np.log(counts))

# %%
sorted([G.degree(x) for x,y in G.nodes(data=True) if y['role']=='ally'])[1:5]
# Out:
# [0, 0, 0, 0]

# %%
sorted([{'name':x, 'value':G.degree(x)} for x,y in G.nodes(data=True) if y['role']=='ally'], key=lambda k: k['value'],reverse=True)[0:5]
# Out:
# [{'name': 'Link', 'value': 396},
#  {'name': 'Hylia', 'value': 70},
#  {'name': 'Princess_Zelda', 'value': 41},
#  {'name': 'Riju', 'value': 30},
#  {'name': 'Purah', 'value': 27}]

# %%
sorted([{'name':x, 'value':G.degree(x)} for x,y in G.nodes(data=True) if y['role']=='enemy'], key=lambda k: k['value'],reverse=True)[0:5]
# Out:
# [{'name': 'Bokoblin', 'value': 31},
#  {'name': 'Moblin', 'value': 24},
#  {'name': 'Lizalfos', 'value': 22},
#  {'name': 'Stalmoblin', 'value': 19},
#  {'name': 'Stalizalfos', 'value': 18}]

# %%
sorted([{'name':x, 'value':G.degree(x)} for x,y in G.nodes(data=True) if y['role']=='boss'], key=lambda k: k['value'],reverse=True)[0:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fe2b6dc72043> in <module>
# ----> 1 sorted([{'name':x, 'value':G.degree(x)} for x,y in G.nodes(data=True) if y['role']=='boss'], key=lambda k: k['value'],reverse=True)[0:5]
#
# NameError: name 'G' is not defined
